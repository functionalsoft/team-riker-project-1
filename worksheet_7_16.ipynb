# %%
import pandas as pd
from prophet import Prophet
import datetime as dt
import numpy as np
from bs4 import BeautifulSoup
import markdown
import string
import re
import matplotlib.pyplot as plt

def remove_html_tags(text):
    return BeautifulSoup(text, "html.parser").get_text()

# Function to remove Markdown
def remove_markdown(text):
    html = markdown.markdown(text)
    return BeautifulSoup(html, "html.parser").get_text()

def clean_row(row):
    return row.apply(lambda x: remove_markdown(remove_html_tags(x)) if isinstance(x, str) else x)

def clean_text(text):
    text = re.sub(r'-', ' ', text)
    text = re.sub(r'#', 'unique', text)
    text = re.sub(r'<strong>', '', text)
    text = re.sub(r'</strong>', ' ', text)
    text = re.sub(r'<em>', ' ', text)
    text = re.sub(r'</em>', ' ', text)
    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Convert to lowercase
    text = text.lower()
    # Replace spaces with dashes
    text = re.sub(r'\s+', '-', text)
    return text

# mhs_2016 = pd.read_csv("resources/2016.csv")
# #mhs_2016 = mhs_2016.apply(clean_row, axis=1)
# mhs_2016.columns = [clean_text(col) for col in mhs_2016.columns]
# #mhs_2016.reset_index(drop=True, inplace=True)
# # set unique column as growing integer
# start = 2016
# stop = 2016 + len(mhs_2016)
# mhs_2016['unique'] = np.arange(start, stop)
# mhs_2016 = mhs_2016.set_index('unique')

mhs_2017 = pd.read_csv("resources/2017.csv")
#mhs_2017 = mhs_2017.apply(clean_row, axis=1)
mhs_2017.columns = [clean_text(col) for col in mhs_2017.columns]
#mhs_2017.reset_index(drop=True, inplace=True)

mhs_2018 = pd.read_csv("resources/2018.csv")
#mhs_2018 = mhs_2018.apply(clean_row, axis=1)
mhs_2018.columns = [clean_text(col) for col in mhs_2018.columns]
#mhs_2018.reset_index(drop=True, inplace=True)

mhs_2019 = pd.read_csv("resources/2019.csv")
#mhs_2018 = mhs_2018.apply(clean_row, axis=1)
mhs_2019.columns = [clean_text(col) for col in mhs_2019.columns]
#mhs_2018.reset_index(drop=True, inplace=True)

mhs_2020 = pd.read_csv("resources/2020.csv")
#mhs_2018 = mhs_2018.apply(clean_row, axis=1)
mhs_2020.columns = [clean_text(col) for col in mhs_2020.columns]
#mhs_2018.reset_index(drop=True, inplace=True)

mhs_2021 = pd.read_csv("resources/2021.csv")
#mhs_2018 = mhs_2018.apply(clean_row, axis=1)
mhs_2021.columns = [clean_text(col) for col in mhs_2021.columns]
#mhs_2018.reset_index(drop=True, inplace=True)

mhs_2022 = pd.read_csv("resources/2022.csv")
#mhs_2018 = mhs_2018.apply(clean_row, axis=1)
mhs_2022.columns = [clean_text(col) for col in mhs_2022.columns]
#mhs_2018.reset_index(drop=True, inplace=True)

mhs_2023 = pd.read_csv("resources/2023.csv")
#mhs_2018 = mhs_2018.apply(clean_row, axis=1)
mhs_2023.columns = [clean_text(col) for col in mhs_2023.columns]
#mhs_2018.reset_index(drop=True, inplace=True)

# %%
mhs_2017.set_index("unique", inplace=True)
mhs_2018.set_index("unique", inplace=True)
mhs_2019.set_index("unique", inplace=True)
mhs_2020.set_index("unique", inplace=True)
mhs_2021.set_index("unique", inplace=True)
mhs_2022.set_index("unique", inplace=True)
mhs_2023.set_index("unique", inplace=True)
mhs_concat = pd.concat([mhs_2017, mhs_2018, mhs_2020, mhs_2021, mhs_2022, mhs_2023], axis=0)

mhs_concat
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/lp/71p77wmn3x7dxlg4mnwx61cw0000gq/T/ipykernel_67807/2500402565.py in ?()
#       1 #mhs_2016.reset_index()
#       2 #mhs_2017.reset_index()
#       3 #mhs_2017_mod=mhs_2017.drop(columns=['columnheading'],axis=0)
#       4 #mhs_2017=mhs_2017.reset_index(drop=True)
# ----> 5 mhs_2017.set_index("unique", inplace=True)
#       6 mhs_2018.set_index("unique", inplace=True)
#       7 mhs_2019.set_index("unique", inplace=True)
#       8 mhs_2020.set_index("unique", inplace=True)
#
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    5866                     if not found:
#    5867                         missing.append(col)
#    5868
#    5869         if missing:
# -> 5870             raise KeyError(f"None of {missing} are in the columns")
#    5871
#    5872         if inplace:
#    5873             frame = self
#
# KeyError: "None of ['unique'] are in the columns"

# %%
mhs_concat
# Out:
#                                   are-you-self-employed-  \
# unique
# e49fe87572831232dcfa51b376b22039                       0
# a1eede444ac024928d247a8372d54931                       0
# 37d3fd67f62bd1e0a2dea4f9cd440d98                       0
# 519b759442c1cab0e9b5a8a1acb1b216                       0
# ef0af4927b575b1a3e607c11ca37870e                       1
# ...                                                  ...
# c7361d89328419b71ccd5f7cae16c818                       0
# c27be4d2a1eb40757e5be080a68b4ca9                       0
# b7bd8db00348415e1e9df49129290e31                       0
# d0a97741b04f1887f43c23839200a195                       0
# 2f601b517e25f2623c6c1e415ea079c8                       0
#
#                                  how-many-employees-does-your-company-or-organization-have  \
# unique
# e49fe87572831232dcfa51b376b22039                                            100-500
# a1eede444ac024928d247a8372d54931                                            100-500
# 37d3fd67f62bd1e0a2dea4f9cd440d98                                               6-25
# 519b759442c1cab0e9b5a8a1acb1b216                                     More than 1000
# ef0af4927b575b1a3e607c11ca37870e                                                NaN
# ...                                                                             ...
# c7361d89328419b71ccd5f7cae16c818                                               6-25
# c27be4d2a1eb40757e5be080a68b4ca9                                            100-500
# b7bd8db00348415e1e9df49129290e31                                            100-500
# d0a97741b04f1887f43c23839200a195                                               6-25
# 2f601b517e25f2623c6c1e415ea079c8                                     More than 1000
#
#                                   is-your-employer-primarily-a-tech-companyorganization  \
# unique
# e49fe87572831232dcfa51b376b22039                                                1.0
# a1eede444ac024928d247a8372d54931                                                1.0
# 37d3fd67f62bd1e0a2dea4f9cd440d98                                                1.0
# 519b759442c1cab0e9b5a8a1acb1b216                                                1.0
# ef0af4927b575b1a3e607c11ca37870e                                                NaN
# ...                                                                             ...
# c7361d89328419b71ccd5f7cae16c818                                                1.0
# c27be4d2a1eb40757e5be080a68b4ca9                                                0.0
# b7bd8db00348415e1e9df49129290e31                                                0.0
# d0a97741b04f1887f43c23839200a195                                                1.0
# 2f601b517e25f2623c6c1e415ea079c8                                                0.0
#
#                                   is-your-primary-role-within-your-company-related-to-techit  \
# unique
# e49fe87572831232dcfa51b376b22039                                                1.0
# a1eede444ac024928d247a8372d54931                                                1.0
# 37d3fd67f62bd1e0a2dea4f9cd440d98                                                1.0
# 519b759442c1cab0e9b5a8a1acb1b216                                                1.0
# ef0af4927b575b1a3e607c11ca37870e                                                NaN
# ...                                                                             ...
# c7361d89328419b71ccd5f7cae16c818                                                1.0
# c27be4d2a1eb40757e5be080a68b4ca9                                                1.0
# b7bd8db00348415e1e9df49129290e31                                                1.0
# d0a97741b04f1887f43c23839200a195                                                1.0
# 2f601b517e25f2623c6c1e415ea079c8                                                1.0
#
#                                  does-your-employer-provide-mental-health-benefits-as-part-of-healthcare-coverage  \
# unique
# e49fe87572831232dcfa51b376b22039                                                 No
# a1eede444ac024928d247a8372d54931                                                Yes
# 37d3fd67f62bd1e0a2dea4f9cd440d98                                       I don't know
# 519b759442c1cab0e9b5a8a1acb1b216                                                Yes
# ef0af4927b575b1a3e607c11ca37870e                                                NaN
# ...                                                                             ...
# c7361d89328419b71ccd5f7cae16c818                                       I don't know
# c27be4d2a1eb40757e5be080a68b4ca9                                                Yes
# b7bd8db00348415e1e9df49129290e31                                                Yes
# d0a97741b04f1887f43c23839200a195                                                Yes
# 2f601b517e25f2623c6c1e415ea079c8                                                Yes
#
#                                  do-you-know-the-options-for-mental-health-care-available-under-your-employer-provided-health-coverage  \
# unique
# e49fe87572831232dcfa51b376b22039                                                Yes
# a1eede444ac024928d247a8372d54931                                                Yes
# 37d3fd67f62bd1e0a2dea4f9cd440d98                                                 No
# 519b759442c1cab0e9b5a8a1acb1b216                                                Yes
# ef0af4927b575b1a3e607c11ca37870e                                                NaN
# ...                                                                             ...
# c7361d89328419b71ccd5f7cae16c818                                                 No
# c27be4d2a1eb40757e5be080a68b4ca9                                                Yes
# b7bd8db00348415e1e9df49129290e31                                                Yes
# d0a97741b04f1887f43c23839200a195                                                Yes
# 2f601b517e25f2623c6c1e415ea079c8                                                Yes
#
#                                  has-your-employer-ever-formally-discussed-mental-health-for-example-as-part-of-a-wellness-campaign-or-other-official-communication  \
# unique
# e49fe87572831232dcfa51b376b22039                                                 No
# a1eede444ac024928d247a8372d54931                                                 No
# 37d3fd67f62bd1e0a2dea4f9cd440d98                                       I don't know
# 519b759442c1cab0e9b5a8a1acb1b216                                       I don't know
# ef0af4927b575b1a3e607c11ca37870e                                                NaN
# ...                                                                             ...
# c7361d89328419b71ccd5f7cae16c818                                                 No
# c27be4d2a1eb40757e5be080a68b4ca9                                                 No
# b7bd8db00348415e1e9df49129290e31                                       I don't know
# d0a97741b04f1887f43c23839200a195                                       I don't know
# 2f601b517e25f2623c6c1e415ea079c8                                                 No
#
#                                  does-your-employer-offer-resources-to-learn-more-about-mental-health-disorders-and-options-for-seeking-help  \
# unique
# e49fe87572831232dcfa51b376b22039                                       I don't know
# a1eede444ac024928d247a8372d54931                                                 No
# 37d3fd67f62bd1e0a2dea4f9cd440d98                                                 No
# 519b759442c1cab0e9b5a8a1acb1b216                                       I don't know
# ef0af4927b575b1a3e607c11ca37870e                                                NaN
# ...                                                                             ...
# c7361d89328419b71ccd5f7cae16c818                                                 No
# c27be4d2a1eb40757e5be080a68b4ca9                                                Yes
# b7bd8db00348415e1e9df49129290e31                                       I don't know
# d0a97741b04f1887f43c23839200a195                                                Yes
# 2f601b517e25f2623c6c1e415ea079c8                                                 No
#
#                                  is-your-anonymity-protected-if-you-choose-to-take-advantage-of-mental-health-or-substance-abuse-treatment-resources-provided-by-your-employer  \
# unique
# e49fe87572831232dcfa51b376b22039                                       I don't know
# a1eede444ac024928d247a8372d54931                                       I don't know
# 37d3fd67f62bd1e0a2dea4f9cd440d98                                                Yes
# 519b759442c1cab0e9b5a8a1acb1b216                                                Yes
# ef0af4927b575b1a3e607c11ca37870e                                                NaN
# ...                                                                             ...
# c7361d89328419b71ccd5f7cae16c818                                       I don't know
# c27be4d2a1eb40757e5be080a68b4ca9                                                Yes
# b7bd8db00348415e1e9df49129290e31                                       I don't know
# d0a97741b04f1887f43c23839200a195                                       I don't know
# 2f601b517e25f2623c6c1e415ea079c8                                                Yes
#
#                                  if-a-mental-health-issue-prompted-you-to-request-a-medical-leave-from-work-how-easy-or-difficult-would-it-be-to-ask-for-that-leave  \
# unique
# e49fe87572831232dcfa51b376b22039                                       I don't know
# a1eede444ac024928d247a8372d54931                                       I don't know
# 37d3fd67f62bd1e0a2dea4f9cd440d98                                          Difficult
# 519b759442c1cab0e9b5a8a1acb1b216                                          Difficult
# ef0af4927b575b1a3e607c11ca37870e                                                NaN
# ...                                                                             ...
# c7361d89328419b71ccd5f7cae16c818                                          Very easy
# c27be4d2a1eb40757e5be080a68b4ca9                                          Difficult
# b7bd8db00348415e1e9df49129290e31                                       I don't know
# d0a97741b04f1887f43c23839200a195                                      Somewhat easy
# 2f601b517e25f2623c6c1e415ea079c8                                       I don't know
#
#                                   ... what-is-your-gender  \
# unique                            ...
# e49fe87572831232dcfa51b376b22039  ...              Female
# a1eede444ac024928d247a8372d54931  ...                male
# 37d3fd67f62bd1e0a2dea4f9cd440d98  ...                male
# 519b759442c1cab0e9b5a8a1acb1b216  ...                Male
# ef0af4927b575b1a3e607c11ca37870e  ...              female
# ...                               ...                 ...
# c7361d89328419b71ccd5f7cae16c818  ...                Male
# c27be4d2a1eb40757e5be080a68b4ca9  ...                Male
# b7bd8db00348415e1e9df49129290e31  ...                Male
# d0a97741b04f1887f43c23839200a195  ...                Male
# 2f601b517e25f2623c6c1e415ea079c8  ...                Male
#
#                                  what-country-do-you-live-in  \
# unique
# e49fe87572831232dcfa51b376b22039              United Kingdom
# a1eede444ac024928d247a8372d54931              United Kingdom
# 37d3fd67f62bd1e0a2dea4f9cd440d98    United States of America
# 519b759442c1cab0e9b5a8a1acb1b216    United States of America
# ef0af4927b575b1a3e607c11ca37870e    United States of America
# ...                                                      ...
# c7361d89328419b71ccd5f7cae16c818    United States of America
# c27be4d2a1eb40757e5be080a68b4ca9                     Finland
# b7bd8db00348415e1e9df49129290e31    United States of America
# d0a97741b04f1887f43c23839200a195    United States of America
# 2f601b517e25f2623c6c1e415ea079c8    United States of America
#
#                                   what-us-state-or-territory-do-you-live-in  \
# unique
# e49fe87572831232dcfa51b376b22039                                        NaN
# a1eede444ac024928d247a8372d54931                                        NaN
# 37d3fd67f62bd1e0a2dea4f9cd440d98                                   Missouri
# 519b759442c1cab0e9b5a8a1acb1b216                                 Washington
# ef0af4927b575b1a3e607c11ca37870e                                   Illinois
# ...                                                                     ...
# c7361d89328419b71ccd5f7cae16c818                                  Tennessee
# c27be4d2a1eb40757e5be080a68b4ca9                                        NaN
# b7bd8db00348415e1e9df49129290e31                                 New Jersey
# d0a97741b04f1887f43c23839200a195                                  Tennessee
# 2f601b517e25f2623c6c1e415ea079c8                                  Tennessee
#
#                                            what-is-your-race       other3  \
# unique
# e49fe87572831232dcfa51b376b22039                         NaN          NaN
# a1eede444ac024928d247a8372d54931                         NaN          NaN
# 37d3fd67f62bd1e0a2dea4f9cd440d98                       White          NaN
# 519b759442c1cab0e9b5a8a1acb1b216                       White          NaN
# ef0af4927b575b1a3e607c11ca37870e  More than one of the above          NaN
# ...                                                      ...          ...
# c7361d89328419b71ccd5f7cae16c818  More than one of the above          NaN
# c27be4d2a1eb40757e5be080a68b4ca9                         NaN          NaN
# b7bd8db00348415e1e9df49129290e31                         NaN  South Asian
# d0a97741b04f1887f43c23839200a195                       White          NaN
# 2f601b517e25f2623c6c1e415ea079c8                       White          NaN
#
#                                   what-country-do-you-work-in  \
# unique
# e49fe87572831232dcfa51b376b22039               United Kingdom
# a1eede444ac024928d247a8372d54931               United Kingdom
# 37d3fd67f62bd1e0a2dea4f9cd440d98     United States of America
# 519b759442c1cab0e9b5a8a1acb1b216     United States of America
# ef0af4927b575b1a3e607c11ca37870e     United States of America
# ...                                                       ...
# c7361d89328419b71ccd5f7cae16c818     United States of America
# c27be4d2a1eb40757e5be080a68b4ca9                      Finland
# b7bd8db00348415e1e9df49129290e31     United States of America
# d0a97741b04f1887f43c23839200a195     United States of America
# 2f601b517e25f2623c6c1e415ea079c8     United States of America
#
#                                  what-us-state-or-territory-do-you-work-in  \
# unique
# e49fe87572831232dcfa51b376b22039                                       NaN
# a1eede444ac024928d247a8372d54931                                       NaN
# 37d3fd67f62bd1e0a2dea4f9cd440d98                                  Missouri
# 519b759442c1cab0e9b5a8a1acb1b216                                Washington
# ef0af4927b575b1a3e607c11ca37870e                                  Illinois
# ...                                                                    ...
# c7361d89328419b71ccd5f7cae16c818                                 Tennessee
# c27be4d2a1eb40757e5be080a68b4ca9                                       NaN
# b7bd8db00348415e1e9df49129290e31                                New Jersey
# d0a97741b04f1887f43c23839200a195                                 Tennessee
# 2f601b517e25f2623c6c1e415ea079c8                                 Tennessee
#
#                                        start-date-utc      submit-date-utc  \
# unique
# e49fe87572831232dcfa51b376b22039  2018-05-16 12:32:04  2018-05-16 12:42:40
# a1eede444ac024928d247a8372d54931  2018-05-16 12:31:13  2018-05-16 12:40:40
# 37d3fd67f62bd1e0a2dea4f9cd440d98  2018-05-09 05:34:05  2018-05-09 05:46:04
# 519b759442c1cab0e9b5a8a1acb1b216  2018-05-04 23:19:14  2018-05-04 23:23:23
# ef0af4927b575b1a3e607c11ca37870e  2018-05-03 00:40:24  2018-05-03 00:53:20
# ...                                               ...                  ...
# c7361d89328419b71ccd5f7cae16c818  2018-05-24 17:55:57  2018-05-24 18:04:13
# c27be4d2a1eb40757e5be080a68b4ca9  2018-05-24 17:34:07  2018-05-24 17:53:00
# b7bd8db00348415e1e9df49129290e31  2018-05-24 17:35:11  2018-05-24 17:48:38
# d0a97741b04f1887f43c23839200a195  2018-05-24 17:38:05  2018-05-24 17:47:25
# 2f601b517e25f2623c6c1e415ea079c8  2018-05-24 17:16:32  2018-05-24 17:23:59
#
#                                   network-id
# unique
# e49fe87572831232dcfa51b376b22039  464b7a12f1
# a1eede444ac024928d247a8372d54931  464b7a12f1
# 37d3fd67f62bd1e0a2dea4f9cd440d98  1eb7e0cb94
# 519b759442c1cab0e9b5a8a1acb1b216  63852edbc4
# ef0af4927b575b1a3e607c11ca37870e  43237889f1
# ...                                      ...
# c7361d89328419b71ccd5f7cae16c818  ee329366d1
# c27be4d2a1eb40757e5be080a68b4ca9  17e8491cd6
# b7bd8db00348415e1e9df49129290e31  6bf2230231
# d0a97741b04f1887f43c23839200a195  26df20fea3
# 2f601b517e25f2623c6c1e415ea079c8  e9bdfa165f
#
# [1173 rows x 122 columns]

# %%
def remove_html_tags(text):
    return BeautifulSoup(text, "html.parser").get_text()

# Function to remove Markdown
def remove_markdown(text):
    html = markdown.markdown(text)
    return BeautifulSoup(html, "html.parser").get_text()

def clean_row(row):
    return row.apply(lambda x: remove_markdown(remove_html_tags(x)) if isinstance(x, str) else x)

def clean_text(text):
    text = re.sub(r'-', ' ', text)
    text = re.sub(r'#', 'Column_Heading', text)
    text = re.sub(r'<strong>', '', text)
    text = re.sub(r'</strong>', '', text)
    text = re.sub(r'<em>', '', text)
    text = re.sub(r'</em>', '', text)
    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Convert to lowercase
    text = text.lower()
    # Replace spaces with dashes
    text = re.sub(r'\s+', '-', text)
    return text
mhs_concat = mhs_concat.apply(clean_row, axis=1)
#mhs_concat.columns = [clean_text(col) for col in mhs_2016.columns]
#mhs_concat.reset_index(drop=True, inplace=True)
# Out:
# /var/folders/lp/71p77wmn3x7dxlg4mnwx61cw0000gq/T/ipykernel_67807/550263750.py:2: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   return BeautifulSoup(text, "html.parser").get_text()

# %%
mhs_concat
# Out:
#                                   are-you-self-employed-  \
# unique
# e49fe87572831232dcfa51b376b22039                       0
# a1eede444ac024928d247a8372d54931                       0
# 37d3fd67f62bd1e0a2dea4f9cd440d98                       0
# 519b759442c1cab0e9b5a8a1acb1b216                       0
# ef0af4927b575b1a3e607c11ca37870e                       1
# ...                                                  ...
# c7361d89328419b71ccd5f7cae16c818                       0
# c27be4d2a1eb40757e5be080a68b4ca9                       0
# b7bd8db00348415e1e9df49129290e31                       0
# d0a97741b04f1887f43c23839200a195                       0
# 2f601b517e25f2623c6c1e415ea079c8                       0
#
#                                  how-many-employees-does-your-company-or-organization-have  \
# unique
# e49fe87572831232dcfa51b376b22039                                            100-500
# a1eede444ac024928d247a8372d54931                                            100-500
# 37d3fd67f62bd1e0a2dea4f9cd440d98                                               6-25
# 519b759442c1cab0e9b5a8a1acb1b216                                     More than 1000
# ef0af4927b575b1a3e607c11ca37870e                                                NaN
# ...                                                                             ...
# c7361d89328419b71ccd5f7cae16c818                                               6-25
# c27be4d2a1eb40757e5be080a68b4ca9                                            100-500
# b7bd8db00348415e1e9df49129290e31                                            100-500
# d0a97741b04f1887f43c23839200a195                                               6-25
# 2f601b517e25f2623c6c1e415ea079c8                                     More than 1000
#
#                                   is-your-employer-primarily-a-tech-companyorganization  \
# unique
# e49fe87572831232dcfa51b376b22039                                                1.0
# a1eede444ac024928d247a8372d54931                                                1.0
# 37d3fd67f62bd1e0a2dea4f9cd440d98                                                1.0
# 519b759442c1cab0e9b5a8a1acb1b216                                                1.0
# ef0af4927b575b1a3e607c11ca37870e                                                NaN
# ...                                                                             ...
# c7361d89328419b71ccd5f7cae16c818                                                1.0
# c27be4d2a1eb40757e5be080a68b4ca9                                                0.0
# b7bd8db00348415e1e9df49129290e31                                                0.0
# d0a97741b04f1887f43c23839200a195                                                1.0
# 2f601b517e25f2623c6c1e415ea079c8                                                0.0
#
#                                   is-your-primary-role-within-your-company-related-to-techit  \
# unique
# e49fe87572831232dcfa51b376b22039                                                1.0
# a1eede444ac024928d247a8372d54931                                                1.0
# 37d3fd67f62bd1e0a2dea4f9cd440d98                                                1.0
# 519b759442c1cab0e9b5a8a1acb1b216                                                1.0
# ef0af4927b575b1a3e607c11ca37870e                                                NaN
# ...                                                                             ...
# c7361d89328419b71ccd5f7cae16c818                                                1.0
# c27be4d2a1eb40757e5be080a68b4ca9                                                1.0
# b7bd8db00348415e1e9df49129290e31                                                1.0
# d0a97741b04f1887f43c23839200a195                                                1.0
# 2f601b517e25f2623c6c1e415ea079c8                                                1.0
#
#                                  does-your-employer-provide-mental-health-benefits-as-part-of-healthcare-coverage  \
# unique
# e49fe87572831232dcfa51b376b22039                                                 No
# a1eede444ac024928d247a8372d54931                                                Yes
# 37d3fd67f62bd1e0a2dea4f9cd440d98                                       I don't know
# 519b759442c1cab0e9b5a8a1acb1b216                                                Yes
# ef0af4927b575b1a3e607c11ca37870e                                                NaN
# ...                                                                             ...
# c7361d89328419b71ccd5f7cae16c818                                       I don't know
# c27be4d2a1eb40757e5be080a68b4ca9                                                Yes
# b7bd8db00348415e1e9df49129290e31                                                Yes
# d0a97741b04f1887f43c23839200a195                                                Yes
# 2f601b517e25f2623c6c1e415ea079c8                                                Yes
#
#                                  do-you-know-the-options-for-mental-health-care-available-under-your-employer-provided-health-coverage  \
# unique
# e49fe87572831232dcfa51b376b22039                                                Yes
# a1eede444ac024928d247a8372d54931                                                Yes
# 37d3fd67f62bd1e0a2dea4f9cd440d98                                                 No
# 519b759442c1cab0e9b5a8a1acb1b216                                                Yes
# ef0af4927b575b1a3e607c11ca37870e                                                NaN
# ...                                                                             ...
# c7361d89328419b71ccd5f7cae16c818                                                 No
# c27be4d2a1eb40757e5be080a68b4ca9                                                Yes
# b7bd8db00348415e1e9df49129290e31                                                Yes
# d0a97741b04f1887f43c23839200a195                                                Yes
# 2f601b517e25f2623c6c1e415ea079c8                                                Yes
#
#                                  has-your-employer-ever-formally-discussed-mental-health-for-example-as-part-of-a-wellness-campaign-or-other-official-communication  \
# unique
# e49fe87572831232dcfa51b376b22039                                                 No
# a1eede444ac024928d247a8372d54931                                                 No
# 37d3fd67f62bd1e0a2dea4f9cd440d98                                       I don't know
# 519b759442c1cab0e9b5a8a1acb1b216                                       I don't know
# ef0af4927b575b1a3e607c11ca37870e                                                NaN
# ...                                                                             ...
# c7361d89328419b71ccd5f7cae16c818                                                 No
# c27be4d2a1eb40757e5be080a68b4ca9                                                 No
# b7bd8db00348415e1e9df49129290e31                                       I don't know
# d0a97741b04f1887f43c23839200a195                                       I don't know
# 2f601b517e25f2623c6c1e415ea079c8                                                 No
#
#                                  does-your-employer-offer-resources-to-learn-more-about-mental-health-disorders-and-options-for-seeking-help  \
# unique
# e49fe87572831232dcfa51b376b22039                                       I don't know
# a1eede444ac024928d247a8372d54931                                                 No
# 37d3fd67f62bd1e0a2dea4f9cd440d98                                                 No
# 519b759442c1cab0e9b5a8a1acb1b216                                       I don't know
# ef0af4927b575b1a3e607c11ca37870e                                                NaN
# ...                                                                             ...
# c7361d89328419b71ccd5f7cae16c818                                                 No
# c27be4d2a1eb40757e5be080a68b4ca9                                                Yes
# b7bd8db00348415e1e9df49129290e31                                       I don't know
# d0a97741b04f1887f43c23839200a195                                                Yes
# 2f601b517e25f2623c6c1e415ea079c8                                                 No
#
#                                  is-your-anonymity-protected-if-you-choose-to-take-advantage-of-mental-health-or-substance-abuse-treatment-resources-provided-by-your-employer  \
# unique
# e49fe87572831232dcfa51b376b22039                                       I don't know
# a1eede444ac024928d247a8372d54931                                       I don't know
# 37d3fd67f62bd1e0a2dea4f9cd440d98                                                Yes
# 519b759442c1cab0e9b5a8a1acb1b216                                                Yes
# ef0af4927b575b1a3e607c11ca37870e                                                NaN
# ...                                                                             ...
# c7361d89328419b71ccd5f7cae16c818                                       I don't know
# c27be4d2a1eb40757e5be080a68b4ca9                                                Yes
# b7bd8db00348415e1e9df49129290e31                                       I don't know
# d0a97741b04f1887f43c23839200a195                                       I don't know
# 2f601b517e25f2623c6c1e415ea079c8                                                Yes
#
#                                  if-a-mental-health-issue-prompted-you-to-request-a-medical-leave-from-work-how-easy-or-difficult-would-it-be-to-ask-for-that-leave  \
# unique
# e49fe87572831232dcfa51b376b22039                                       I don't know
# a1eede444ac024928d247a8372d54931                                       I don't know
# 37d3fd67f62bd1e0a2dea4f9cd440d98                                          Difficult
# 519b759442c1cab0e9b5a8a1acb1b216                                          Difficult
# ef0af4927b575b1a3e607c11ca37870e                                                NaN
# ...                                                                             ...
# c7361d89328419b71ccd5f7cae16c818                                          Very easy
# c27be4d2a1eb40757e5be080a68b4ca9                                          Difficult
# b7bd8db00348415e1e9df49129290e31                                       I don't know
# d0a97741b04f1887f43c23839200a195                                      Somewhat easy
# 2f601b517e25f2623c6c1e415ea079c8                                       I don't know
#
#                                   ... what-is-your-gender  \
# unique                            ...
# e49fe87572831232dcfa51b376b22039  ...              Female
# a1eede444ac024928d247a8372d54931  ...                male
# 37d3fd67f62bd1e0a2dea4f9cd440d98  ...                male
# 519b759442c1cab0e9b5a8a1acb1b216  ...                Male
# ef0af4927b575b1a3e607c11ca37870e  ...              female
# ...                               ...                 ...
# c7361d89328419b71ccd5f7cae16c818  ...                Male
# c27be4d2a1eb40757e5be080a68b4ca9  ...                Male
# b7bd8db00348415e1e9df49129290e31  ...                Male
# d0a97741b04f1887f43c23839200a195  ...                Male
# 2f601b517e25f2623c6c1e415ea079c8  ...                Male
#
#                                  what-country-do-you-live-in  \
# unique
# e49fe87572831232dcfa51b376b22039              United Kingdom
# a1eede444ac024928d247a8372d54931              United Kingdom
# 37d3fd67f62bd1e0a2dea4f9cd440d98    United States of America
# 519b759442c1cab0e9b5a8a1acb1b216    United States of America
# ef0af4927b575b1a3e607c11ca37870e    United States of America
# ...                                                      ...
# c7361d89328419b71ccd5f7cae16c818    United States of America
# c27be4d2a1eb40757e5be080a68b4ca9                     Finland
# b7bd8db00348415e1e9df49129290e31    United States of America
# d0a97741b04f1887f43c23839200a195    United States of America
# 2f601b517e25f2623c6c1e415ea079c8    United States of America
#
#                                   what-us-state-or-territory-do-you-live-in  \
# unique
# e49fe87572831232dcfa51b376b22039                                        NaN
# a1eede444ac024928d247a8372d54931                                        NaN
# 37d3fd67f62bd1e0a2dea4f9cd440d98                                   Missouri
# 519b759442c1cab0e9b5a8a1acb1b216                                 Washington
# ef0af4927b575b1a3e607c11ca37870e                                   Illinois
# ...                                                                     ...
# c7361d89328419b71ccd5f7cae16c818                                  Tennessee
# c27be4d2a1eb40757e5be080a68b4ca9                                        NaN
# b7bd8db00348415e1e9df49129290e31                                 New Jersey
# d0a97741b04f1887f43c23839200a195                                  Tennessee
# 2f601b517e25f2623c6c1e415ea079c8                                  Tennessee
#
#                                            what-is-your-race       other3  \
# unique
# e49fe87572831232dcfa51b376b22039                         NaN          NaN
# a1eede444ac024928d247a8372d54931                         NaN          NaN
# 37d3fd67f62bd1e0a2dea4f9cd440d98                       White          NaN
# 519b759442c1cab0e9b5a8a1acb1b216                       White          NaN
# ef0af4927b575b1a3e607c11ca37870e  More than one of the above          NaN
# ...                                                      ...          ...
# c7361d89328419b71ccd5f7cae16c818  More than one of the above          NaN
# c27be4d2a1eb40757e5be080a68b4ca9                         NaN          NaN
# b7bd8db00348415e1e9df49129290e31                         NaN  South Asian
# d0a97741b04f1887f43c23839200a195                       White          NaN
# 2f601b517e25f2623c6c1e415ea079c8                       White          NaN
#
#                                   what-country-do-you-work-in  \
# unique
# e49fe87572831232dcfa51b376b22039               United Kingdom
# a1eede444ac024928d247a8372d54931               United Kingdom
# 37d3fd67f62bd1e0a2dea4f9cd440d98     United States of America
# 519b759442c1cab0e9b5a8a1acb1b216     United States of America
# ef0af4927b575b1a3e607c11ca37870e     United States of America
# ...                                                       ...
# c7361d89328419b71ccd5f7cae16c818     United States of America
# c27be4d2a1eb40757e5be080a68b4ca9                      Finland
# b7bd8db00348415e1e9df49129290e31     United States of America
# d0a97741b04f1887f43c23839200a195     United States of America
# 2f601b517e25f2623c6c1e415ea079c8     United States of America
#
#                                  what-us-state-or-territory-do-you-work-in  \
# unique
# e49fe87572831232dcfa51b376b22039                                       NaN
# a1eede444ac024928d247a8372d54931                                       NaN
# 37d3fd67f62bd1e0a2dea4f9cd440d98                                  Missouri
# 519b759442c1cab0e9b5a8a1acb1b216                                Washington
# ef0af4927b575b1a3e607c11ca37870e                                  Illinois
# ...                                                                    ...
# c7361d89328419b71ccd5f7cae16c818                                 Tennessee
# c27be4d2a1eb40757e5be080a68b4ca9                                       NaN
# b7bd8db00348415e1e9df49129290e31                                New Jersey
# d0a97741b04f1887f43c23839200a195                                 Tennessee
# 2f601b517e25f2623c6c1e415ea079c8                                 Tennessee
#
#                                        start-date-utc      submit-date-utc  \
# unique
# e49fe87572831232dcfa51b376b22039  2018-05-16 12:32:04  2018-05-16 12:42:40
# a1eede444ac024928d247a8372d54931  2018-05-16 12:31:13  2018-05-16 12:40:40
# 37d3fd67f62bd1e0a2dea4f9cd440d98  2018-05-09 05:34:05  2018-05-09 05:46:04
# 519b759442c1cab0e9b5a8a1acb1b216  2018-05-04 23:19:14  2018-05-04 23:23:23
# ef0af4927b575b1a3e607c11ca37870e  2018-05-03 00:40:24  2018-05-03 00:53:20
# ...                                               ...                  ...
# c7361d89328419b71ccd5f7cae16c818  2018-05-24 17:55:57  2018-05-24 18:04:13
# c27be4d2a1eb40757e5be080a68b4ca9  2018-05-24 17:34:07  2018-05-24 17:53:00
# b7bd8db00348415e1e9df49129290e31  2018-05-24 17:35:11  2018-05-24 17:48:38
# d0a97741b04f1887f43c23839200a195  2018-05-24 17:38:05  2018-05-24 17:47:25
# 2f601b517e25f2623c6c1e415ea079c8  2018-05-24 17:16:32  2018-05-24 17:23:59
#
#                                   network-id
# unique
# e49fe87572831232dcfa51b376b22039  464b7a12f1
# a1eede444ac024928d247a8372d54931  464b7a12f1
# 37d3fd67f62bd1e0a2dea4f9cd440d98  1eb7e0cb94
# 519b759442c1cab0e9b5a8a1acb1b216  63852edbc4
# ef0af4927b575b1a3e607c11ca37870e  43237889f1
# ...                                      ...
# c7361d89328419b71ccd5f7cae16c818  ee329366d1
# c27be4d2a1eb40757e5be080a68b4ca9  17e8491cd6
# b7bd8db00348415e1e9df49129290e31  6bf2230231
# d0a97741b04f1887f43c23839200a195  26df20fea3
# 2f601b517e25f2623c6c1e415ea079c8  e9bdfa165f
#
# [1173 rows x 122 columns]

# %%
def remove_html_tags(text):
    return BeautifulSoup(text, "html.parser").get_text()

# Function to remove Markdown
def remove_markdown(text):
    html = markdown.markdown(text)
    return BeautifulSoup(html, "html.parser").get_text()

def clean_row(row):
    return row.apply(lambda x: remove_markdown(remove_html_tags(x)) if isinstance(x, str) else x)

def clean_text(text):
    text = re.sub(r'-', ' ', text)
    text = re.sub(r'#', 'Column_Heading', text)
    text = re.sub(r'<strong>', '', text)
    text = re.sub(r'</strong>', '', text)
    text = re.sub(r'<em>', '', text)
    text = re.sub(r'</em>', '', text)
    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Convert to lowercase
    text = text.lower()
    # Replace spaces with dashes
    text = re.sub(r'\s+', '-', text)
    return text
mhs_concat = mhs_concat.apply(clean_row, axis=1)
#mhs_concat.columns = [clean_text(col) for col in mhs_2016.columns]
#mhs_concat.reset_index(drop=True, inplace=True)
# Out:
# /var/folders/lp/71p77wmn3x7dxlg4mnwx61cw0000gq/T/ipykernel_67807/550263750.py:2: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   return BeautifulSoup(text, "html.parser").get_text()
