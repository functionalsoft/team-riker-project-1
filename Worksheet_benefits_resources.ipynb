# %%
import pandas as pd
from prophet import Prophet
import datetime as dt
import numpy as np
from bs4 import BeautifulSoup
import markdown
import string
import re
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)

def remove_html_tags(text):
    return BeautifulSoup(text, "html.parser").get_text()

# Function to remove Markdown
def remove_markdown(text):
    html = markdown.markdown(text)
    return BeautifulSoup(html+ "html.parser").get_text()

def clean_row(row):
    return row.apply(lambda x: remove_markdown(remove_html_tags(x)) if isinstance(x, str) else x)

def clean_text(text):
    text = re.sub(r'-', ' ', text)
    text = re.sub(r'#', 'unique_column_heading', text)
    text = re.sub(r'None', 'unique_column_heading', text)
    text = re.sub(r'<strong>', '', text)
    text = re.sub(r'</strong>', ' ', text)
    text = re.sub(r'<em>', ' ', text)
    text = re.sub(r'</em>', ' ', text)
    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Convert to lowercase
    text = text.lower()
    # Replace spaces with dashes
    text = re.sub(r'\s+', '-', text)
    return text

def rename_duplicate_columns(mhs_df):
    cols = pd.Series(mhs_df.columns)
    for dup in cols[cols.duplicated()].unique():
        cols[cols[cols == dup].index.values.tolist()] = [dup + '_' + str(i) if i != 0 else dup for i in range(sum(cols == dup))]
    mhs_df.columns = cols
    return mhs_df

def preprocess_df(df):
    df = df.astype(str)
    df = rename_duplicate_columns(df)
    df = df.reset_index(drop=True)
    return df

def merge_columns(df: pd.DataFrame) -> pd.DataFrame:
    merged_columns = {}

    for col in df.columns:
        if col in merged_columns:
            merged_columns[col] = merged_columns[col].fillna('') + ' ' + df[col].fillna('')
        else:
            merged_columns[col] = df[col].fillna('')

    merged_df = pd.DataFrame(merged_columns)

    return merged_df

def reset_index_with_string(df, string):
    df = df.reset_index(drop=True)
    df.index = [f"{string}{i}" for i in df.index.astype(str)]
    return df

# %%
column_mapping = {
    'are-you-self-employed' : 'self-employed', 
    'how-many-employees-does-your-company-or-organization-have' : 'num-employees', 
    'is-your-employer-primarily-a-tech-companyorganization' : 'tech-employer', 
    'is-your-primary-role-within-your-company-related-to-techit' : 'tech-role', 
    'does-your-employer-provide-mental-health-benefits-as-part-of-healthcare-coverage' : 'has-mental-health-benefits', 
    'do-you-know-the-options-for-mental-health-care-available-under-your-employer-provided-health-coverage' : 'know-mental-health-options', 
    'has-your-employer-ever-formally-discussed-mental-health-for-example-as-part-of-a-wellness-campaign-or-other-official-communication' : 'discussed-mental-health', 
    'does-your-employer-offer-resources-to-learn-more-about-mental-health-disorders-and-options-for-seeking-help' : 'has-mental-health-resources', 
    'is-your-anonymity-protected-if-you-choose-to-take-advantage-of-mental-health-or-substance-abuse-treatment-resources-provided-by-your-employer' : 'anonymity-protected', 
    'if-a-mental-health-issue-prompted-you-to-request-a-medical-leave-from-work-how-easy-or-difficult-would-it-be-to-ask-for-that-leave' : 'mental-health-leave-ease', 
    'would-you-feel-more-comfortable-talking-to-your-coworkers-about-your-physical-health-or-your-mental-health' : 'comfort-discussing-health', 
    'would-you-feel-comfortable-discussing-a-mental-health-issue-with-your-direct-supervisors' : 'discuss-mental-health-supervisor', 
    'have-you-ever-discussed-your-mental-health-with-your-employer' : 'discussed-mental-health-employer', 
    'describe-the-conversation-you-had-with-your-employer-about-your-mental-health-including-their-reactions-and-what-actions-were-taken-to-address-your-mental-health-issuequestions' : 'mental-health-talk-employer', 
    'would-you-feel-comfortable-discussing-a-mental-health-issue-with-your-coworkers' : 'discuss-mental-health-coworkers', 
    'have-you-ever-discussed-your-mental-health-with-coworkers' : 'discussed-mental-health-coworkers', 
    'describe-the-conversation-with-coworkers-you-had-about-your-mental-health-including-their-reactions' : 'mental-health-talk-coworkers', 
    'have-you-ever-had-a-coworker-discuss-their-or-another-coworkers-mental-health-with-you' : 'coworker-mental-health-discussion', 
    'describe-the-conversation-your-coworker-had-with-you-about-their-mental-health-please-do-not-use-names' : 'coworker-mental-health-talk', 
    'overall-how-much-importance-does-your-employer-place-on-physical-health' : 'importance-physical-health', 
    'overall-how-much-importance-does-your-employer-place-on-mental-health' : 'importance-mental-health', 
    'do-you-have-medical-coverage-private-insurance-or-state-provided-that-includes-treatment-of-mental-health-disorders' : 'mental-health-coverage', 
    'do-you-know-local-or-online-resources-to-seek-help-for-a-mental-health-issue' : 'know-mental-health-resources', 
    'if-you-have-been-diagnosed-or-treated-for-a-mental-health-disorder-do-you-ever-reveal-this-to-clients-or-business-contacts' : 'reveal-mental-health-clients', 
    'if-you-have-revealed-a-mental-health-disorder-to-a-client-or-business-contact-how-has-this-affected-you-or-the-relationship' : 'effect-reveal-mental-health', 
    'if-you-have-been-diagnosed-or-treated-for-a-mental-health-disorder-do-you-ever-reveal-this-to-coworkers-or-employees' : 'reveal-mental-health-coworkers', 
    'if-you-have-revealed-a-mental-health-disorder-to-a-coworker-or-employee-how-has-this-impacted-you-or-the-relationship' : 'impact-reveal-mental-health', 
    'do-you-believe-your-productivity-is-ever-affected-by-a-mental-health-issue' : 'productivity-mental-health', 
    'if-yes-what-percentage-of-your-work-time-time-performing-primary-or-secondary-job-functions-is-affected-by-a-mental-health-issue' : 'percentage-affected-mental-health', 
    'do-you-have-previous-employers' : 'previous-employers', 
    'was-your-employer-primarily-a-tech-companyorganization' : 'previous-tech-employer', 
    'have-your-previous-employers-provided-mental-health-benefits' : 'previous-mental-health-benefits', 
    'were-you-aware-of-the-options-for-mental-health-care-provided-by-your-previous-employers' : 'aware-previous-mental-health-options', 
    'did-your-previous-employers-ever-formally-discuss-mental-health-as-part-of-a-wellness-campaign-or-other-official-communication' : 'discussed-mental-health-previous', 
    'did-your-previous-employers-provide-resources-to-learn-more-about-mental-health-disorders-and-how-to-seek-help' : 'previous-mental-health-resources', 
    'was-your-anonymity-protected-if-you-chose-to-take-advantage-of-mental-health-or-substance-abuse-treatment-resources-with-previous-employers' : 'previous-anonymity-protected', 
    'would-you-have-felt-more-comfortable-talking-to-your-previous-employer-about-your-physical-health-or-your-mental-health' : 'previous-comfort-discussing-health', 
    'would-you-have-been-willing-to-discuss-your-mental-health-with-your-direct-supervisors' : 'previous-discuss-mental-health-supervisor', 
    'did-you-ever-discuss-your-mental-health-with-your-previous-employer' : 'previous-discussed-mental-health', 
    'describe-the-conversation-you-had-with-your-previous-employer-about-your-mental-health-including-their-reactions-and-actions-taken-to-address-your-mental-health-issuequestions' : 'previous-mental-health-talk-employer', 
    'would-you-have-been-willing-to-discuss-your-mental-health-with-your-coworkers-at-previous-employers' : 'previous-discuss-mental-health-coworkers', 
    'did-you-ever-discuss-your-mental-health-with-a-previous-coworkers' : 'previous-discussed-mental-health-coworkers', 
    'describe-the-conversation-you-had-with-your-previous-coworkers-about-your-mental-health-including-their-reactions' : 'previous-mental-health-talk-coworkers', 
    'did-you-ever-have-a-previous-coworker-discuss-their-or-another-coworkers-mental-health-with-you' : 'previous-coworker-mental-health-discussion', 
    'describe-the-conversation-your-coworker-had-with-you-about-their-mental-health-please-do-not-use-names1' : 'previous-coworker-mental-health-talk', 
    'overall-how-much-importance-did-your-previous-employer-place-on-physical-health' : 'previous-importance-physical-health', 
    'overall-how-much-importance-did-your-previous-employer-place-on-mental-health' : 'previous-importance-mental-health', 
    'do-you-currently-have-a-mental-health-disorder' : 'current-mental-health-disorder', 
    'have-you-ever-been-diagnosed-with-a-mental-health-disorder' : 'diagnosed-mental-health', 
    'anxiety-disorder-generalized-social-phobia-etc' : 'anxiety-disorder', 
    'mood-disorder-depression-bipolar-disorder-etc' : 'mood-disorder', 
    'psychotic-disorder-schizophrenia-schizoaffective-etc' : 'psychotic-disorder', 
    'eating-disorder-anorexia-bulimia-etc' : 'eating-disorder', 
    'attention-deficit-hyperactivity-disorder' : 'adhd', 
    'personality-disorder-borderline-antisocial-paranoid-etc' : 'personality-disorder', 
    'obsessive-compulsive-disorder' : 'ocd', 
    'post-traumatic-stress-disorder' : 'ptsd', 
    'stress-response-syndromes' : 'stress-response', 
    'dissociative-disorder' : 'dissociative-disorder', 
    'substance-use-disorder' : 'substance-use', 
    'addictive-disorder' : 'addictive-disorder', 
    'other' : 'other', 
    'anxiety-disorder-generalized-social-phobia-etc1' : 'anxiety-disorder1', 
    'mood-disorder-depression-bipolar-disorder-etc1' : 'mood-disorder1', 
    'psychotic-disorder-schizophrenia-schizoaffective-etc1' : 'psychotic-disorder1', 
    'eating-disorder-anorexia-bulimia-etc1' : 'eating-disorder1', 
    'attention-deficit-hyperactivity-disorder1' : 'adhd1', 
    'personality-disorder-borderline-antisocial-paranoid-etc1' : 'personality-disorder1', 
    'obsessive-compulsive-disorder1' : 'ocd1', 
    'post-traumatic-stress-disorder' : 'ptsd1', 
    'stress-response-syndromes1' : 'stress-response1', 
    'dissociative-disorder1' : 'dissociative-disorder1', 
    'substance-use-disorder1' : 'substance-use1', 
    'addictive-disorder1' : 'addictive-disorder1', 
    'other1' : 'other1', 
    'anxiety-disorder-generalized-social-phobia-etc2' : 'anxiety-disorder2', 
    'mood-disorder-depression-bipolar-disorder-etc2' : 'mood-disorder2', 
    'psychotic-disorder-schizophrenia-schizoaffective-etc2' : 'psychotic-disorder2', 
    'eating-disorder-anorexia-bulimia-etc2' : 'eating-disorder2', 
    'attention-deficit-hyperactivity-disorder2' : 'adhd2', 
    'personality-disorder-borderline-antisocial-paranoid-etc2' : 'personality-disorder2', 
    'obsessive-compulsive-disorder2' : 'ocd2', 
    'post-traumatic-stress-disorder1' : 'ptsd2', 
    'stress-response-syndromes2' : 'stress-response2', 
    'dissociative-disorder2' : 'dissociative-disorder2', 
    'substance-use-disorder2' : 'substance-use2', 
    'addictive-disorder2' : 'addictive-disorder2', 
    'other2' : 'other2', 
    'have-you-had-a-mental-health-disorder-in-the-past' : 'past-mental-health-disorder', 
    'have-you-ever-sought-treatment-for-a-mental-health-disorder-from-a-mental-health-professional' : 'sought-treatment', 
    'do-you-have-a-family-history-of-mental-illness' : 'family-history-mental-illness', 
    'if-you-have-a-mental-health-disorder-how-often-do-you-feel-that-it-interferes-with-your-work-when-being-treated-effectively' : 'mental-health-interference-treated', 
    'if-you-have-a-mental-health-disorder-how-often-do-you-feel-that-it-interferes-with-your-work-when-not-being-treated-effectively-ie-when-you-are-experiencing-symptoms' : 'mental-health-interference-untreated', 
    'have-your-observations-of-how-another-individual-who-discussed-a-mental-health-issue-made-you-less-likely-to-reveal-a-mental-health-issue-yourself-in-your-current-workplace' : 'observations-mental-health-discussion', 
    'how-willing-would-you-be-to-share-with-friends-and-family-that-you-have-a-mental-illness' : 'share-mental-illness', 
    'would-you-be-willing-to-bring-up-a-physical-health-issue-with-a-potential-employer-in-an-interview' : 'physical-health-interview', 
    'why-or-why-not' : 'physical-health-reason', 
    'would-you-bring-up-your-mental-health-with-a-potential-employer-in-an-interview' : 'mental-health-interview', 
    'why-or-why-not1' : 'mental-health-reason', 
    'are-you-openly-identified-at-work-as-a-person-with-a-mental-health-issue' : 'open-mental-health', 
    'has-being-identified-as-a-person-with-a-mental-health-issue-affected-your-career' : 'mental-health-career', 
    'how-has-it-affected-your-career' : 'mental-health-career-effect', 
    'if-they-knew-you-suffered-from-a-mental-health-disorder-how-do-you-think-that-your-team-membersco-workers-would-react' : 'team-reaction', 
    'have-you-observed-or-experienced-an-unsupportive-or-badly-handled-response-to-a-mental-health-issue-in-your-current-or-previous-workplace' : 'unsupportive-response', 
    'describe-the-circumstances-of-the-badly-handled-or-unsupportive-response' : 'unsupportive-response-details', 
    'have-you-observed-or-experienced-a-supportive-or-well-handled-response-to-a-mental-health-issue-in-your-current-or-previous-workplace' : 'supportive-response', 
    'describe-the-circumstances-of-the-supportive-or-well-handled-response' : 'supportive-response-details', 
    'overall-how-well-do-you-think-the-tech-industry-supports-employees-with-mental-health-issues' : 'industry-support', 
    'briefly-describe-what-you-think-the-industry-as-a-whole-andor-employers-could-do-to-improve-mental-health-support-for-employees' : 'improve-industry-support', 
    'if-there-is-anything-else-you-would-like-to-tell-us-that-has-not-been-covered-by-the-survey-questions-please-use-this-space-to-do-so' : 'additional-comments', 
    'would-you-be-willing-to-talk-to-one-of-us-more-extensively-about-your-experiences-with-mental-health-issues-in-the-tech-industry-note-that-all-interview-responses-would-be-used-anonymously-and-only-with-your-permission' : 'interview-mental-health', 
    'what-is-your-age' : 'age', 
    'what-is-your-gender' : 'gender', 
    'what-country-do-you-live-in' : 'country-live', 
    'what-us-state-or-territory-do-you-live-in' : 'us-state-live', 
    'what-is-your-race' : 'race', 
    'other3' : 'other3', 
    'what-country-do-you-work-in' : 'country-work', 
    'what-us-state-or-territory-do-you-work-in' : 'us-state-work', 
    'have-you-been-diagnosed-with-covid-19' : 'covid-19-diagnosis', 
    'response-type' : 'response-type', 
    'start-date-utc' : 'start-date', 
    'submit-date-utc' : 'submit-date', 
    'network-id' : 'network-id', 
    'tags' : 'tags'
}

cols_kept=['year','country-live','race','gender','age',
           'anxiety-disorder','anxiety-disorder1','anxiety-disorder2',
           'mood-disorder','mood-disorder1','mood-disorder2',
           'psychotic-disorder','psychotic-disorder1','psychotic-disorder2',
           'eating-disorder','eating-disorder1','eating-disorder2',
           'adhd','adhd1','adhd2',
           'personality-disorder','personality-disorder1','personality-disorder2',
           'ocd','ocd1','ocd2',
           'ptsd1','ptsd2',
           'stress-response','stress-response1','stress-response2',
           'dissociative-disorder','dissociative-disorder1','dissociative-disorder2',
           'substance-use','substance-use1','substance-use2',
           'addictive-disorder','addictive-disorder1','addictive-disorder2',
           'other','other1','other2']

# For 2020
mhs_2020 = pd.read_csv("resources/2020.csv", index_col=False)
mhs_2020["year"] = 2020
mhs_2020.columns = [clean_text(col) for col in mhs_2020.columns]
# mhs_2020 = mhs_2020.apply(clean_row, axis=1)
mhs_2020 = preprocess_df(mhs_2020)
mhs_2020.rename(columns=column_mapping, inplace=True)
mhs_2020_fin=mhs_2020 #[cols_kept]
display(mhs_2020_fin.info())
column_names_2020 = mhs_2020_fin.columns.tolist()
print(len(column_names_2020))

# For 2021
mhs_2021 = pd.read_csv("resources/2021.csv", index_col=False)
mhs_2021["year"] = 2021
mhs_2021.columns = [clean_text(col) for col in mhs_2021.columns]
# mhs_2021 = mhs_2021.apply(clean_row, axis=1)
mhs_2021 = preprocess_df(mhs_2021)
mhs_2021.rename(columns=column_mapping, inplace=True)
mhs_2021_fin=mhs_2021 #[cols_kept]
display(mhs_2021_fin.info())
column_names_2021 = mhs_2021_fin.columns.tolist()
print(len(column_names_2021))

# For 2022
mhs_2022 = pd.read_csv("resources/2022.csv", index_col=False)
mhs_2022["year"] = 2022
mhs_2022.columns = [clean_text(col) for col in mhs_2022.columns]
# mhs_2022 = mhs_2022.apply(clean_row, axis=1)
mhs_2022 = preprocess_df(mhs_2022)
mhs_2022.rename(columns=column_mapping, inplace=True)
mhs_2022_fin=mhs_2022 #[cols_kept]
display(mhs_2022_fin.info())
column_names_2022 = mhs_2022_fin.columns.tolist()
print(len(column_names_2022))

# For 2023
mhs_2023 = pd.read_csv("resources/2023.csv", index_col=False)
mhs_2023["year"] = 2023
mhs_2023.columns = [clean_text(col) for col in mhs_2023.columns]
# mhs_2023 = mhs_2023.apply(clean_row, axis=1)
mhs_2023 = preprocess_df(mhs_2023)
mhs_2023.rename(columns=column_mapping, inplace=True)
mhs_2023_fin=mhs_2023 #[cols_kept]
display(mhs_2023_fin.info())
column_names_2023 = mhs_2023_fin.columns.tolist()
print(len(column_names_2023))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Columns: 121 entries, uniquecolumnheading to year
# dtypes: object(121)
# memory usage: 170.3+ KB
# None
# 121
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131 entries, 0 to 130
# Columns: 125 entries, uniquecolumnheading to year
# dtypes: object(125)
# memory usage: 128.1+ KB
# None
# 125
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 164 entries, 0 to 163
# Columns: 125 entries, uniquecolumnheading to year
# dtypes: object(125)
# memory usage: 160.3+ KB
# None
# 125
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Columns: 125 entries, uniquecolumnheading to year
# dtypes: object(125)
# memory usage: 6.0+ KB
# None
# 125

# %%
mhs_2020_fin = reset_index_with_string(mhs_2020_fin, "2020_")
mhs_2021_fin = reset_index_with_string(mhs_2021_fin, "2021_")
mhs_2022_fin = reset_index_with_string(mhs_2022_fin, "2022_")
mhs_2023_fin = reset_index_with_string(mhs_2023_fin, "2023_")

# %%
merged_mhs = pd.concat([mhs_2020_fin, mhs_2021_fin, mhs_2022_fin, mhs_2023_fin], axis=0)
merged_mhs.to_csv("resources/merged_mhs_dc.csv", index=False)

# %%
merged_mhs.convert_dtypes()
merged_mhs.dtypes

# merged_mhs.plot(kind='bar', x='year', y='age')
# plt.show()
# Out:
# uniquecolumnheading                           object
# self-employed                                 object
# num-employees                                 object
# tech-employer                                 object
# tech-role                                     object
# has-mental-health-benefits                    object
# know-mental-health-options                    object
# discussed-mental-health                       object
# has-mental-health-resources                   object
# anonymity-protected                           object
# mental-health-leave-ease                      object
# comfort-discussing-health                     object
# discuss-mental-health-supervisor              object
# discussed-mental-health-employer              object
# mental-health-talk-employer                   object
# discuss-mental-health-coworkers               object
# discussed-mental-health-coworkers             object
# mental-health-talk-coworkers                  object
# coworker-mental-health-discussion             object
# coworker-mental-health-talk                   object
# importance-physical-health                    object
# importance-mental-health                      object
# mental-health-coverage                        object
# know-mental-health-resources                  object
# reveal-mental-health-clients                  object
# effect-reveal-mental-health                   object
# reveal-mental-health-coworkers                object
# impact-reveal-mental-health                   object
# productivity-mental-health                    object
# percentage-affected-mental-health             object
# previous-employers                            object
# previous-tech-employer                        object
# previous-mental-health-benefits               object
# aware-previous-mental-health-options          object
# discussed-mental-health-previous              object
# previous-mental-health-resources              object
# previous-anonymity-protected                  object
# previous-comfort-discussing-health            object
# previous-discuss-mental-health-supervisor     object
# previous-discussed-mental-health              object
# previous-mental-health-talk-employer          object
# previous-discuss-mental-health-coworkers      object
# previous-discussed-mental-health-coworkers    object
# previous-mental-health-talk-coworkers         object
# previous-coworker-mental-health-discussion    object
# previous-coworker-mental-health-talk          object
# previous-importance-physical-health           object
# previous-importance-mental-health             object
# current-mental-health-disorder                object
# diagnosed-mental-health                       object
# anxiety-disorder                              object
# mood-disorder                                 object
# psychotic-disorder                            object
# eating-disorder                               object
# adhd                                          object
# personality-disorder                          object
# ocd                                           object
# ptsd1                                         object
# stress-response                               object
# dissociative-disorder                         object
# substance-use                                 object
# addictive-disorder                            object
# other                                         object
# anxiety-disorder1                             object
# mood-disorder1                                object
# psychotic-disorder1                           object
# eating-disorder1                              object
# adhd1                                         object
# personality-disorder1                         object
# ocd1                                          object
# post-traumatic-stress-disorder_1              object
# stress-response1                              object
# dissociative-disorder1                        object
# substance-use1                                object
# addictive-disorder1                           object
# other1                                        object
# anxiety-disorder2                             object
# mood-disorder2                                object
# psychotic-disorder2                           object
# eating-disorder2                              object
# adhd2                                         object
# personality-disorder2                         object
# ocd2                                          object
# ptsd2                                         object
# stress-response2                              object
# dissociative-disorder2                        object
# substance-use2                                object
# addictive-disorder2                           object
# other2                                        object
# past-mental-health-disorder                   object
# sought-treatment                              object
# family-history-mental-illness                 object
# mental-health-interference-treated            object
# mental-health-interference-untreated          object
# observations-mental-health-discussion         object
# share-mental-illness                          object
# physical-health-interview                     object
# physical-health-reason                        object
# mental-health-interview                       object
# mental-health-reason                          object
# open-mental-health                            object
# mental-health-career                          object
# mental-health-career-effect                   object
# team-reaction                                 object
# unsupportive-response                         object
# unsupportive-response-details                 object
# supportive-response                           object
# supportive-response-details                   object
# industry-support                              object
# improve-industry-support                      object
# additional-comments                           object
# interview-mental-health                       object
# age                                           object
# gender                                        object
# country-live                                  object
# us-state-live                                 object
# race                                          object
# other3                                        object
# country-work                                  object
# us-state-work                                 object
# year                                          object
# covid-19-diagnosis                            object
# start-date                                    object
# submit-date                                   object
# network-id                                    object
# dtype: object

# %%
# merged_mhs=merged_mhs.reset_index()

cols_to_concat=["anxiety-disorder",'anxiety-disorder1','anxiety-disorder2',
           'mood-disorder','mood-disorder1','mood-disorder2',
           'psychotic-disorder','psychotic-disorder1','psychotic-disorder2',
           'eating-disorder','eating-disorder1','eating-disorder2',
           'adhd','adhd1','adhd2',
           'personality-disorder','personality-disorder1','personality-disorder2',
           'ocd','ocd1','ocd2',
           'ptsd1','ptsd2',
           'stress-response','stress-response1','stress-response2',
           'dissociative-disorder','dissociative-disorder1','dissociative-disorder2',
           'substance-use','substance-use1','substance-use2',
           'addictive-disorder','addictive-disorder1','addictive-disorder2',
           'other','other1','other2']

concatenated_series = merged_mhs[cols_to_concat].apply(lambda row: '| '.join(str(val) for val in row), axis=1)

merged_mhs['disorders'] = concatenated_series
merged_mhs['disorders'] = merged_mhs['disorders'].str.replace("nan|", '')
merged_mhs['disorders'] = merged_mhs['disorders'].str.replace("nan", '')
merged_mhs['disorders'] = merged_mhs['disorders'].str.replace(", ", '||')
merged_mhs['disorders'] = merged_mhs['disorders'].str.replace(" ", '')
merged_mhs['disorders'] = merged_mhs['disorders'].str.replace("||", ', ')
merged_mhs.drop(columns=cols_to_concat, inplace=True)

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
merged_mhs['race'] = merged_mhs['race'].str.replace("More than one of the above", 'Multi')
merged_mhs['race'] = merged_mhs['race'].str.replace("nan", 'Unknown')
merged_mhs['race'] = merged_mhs['race'].str.replace("I prefer not to answer", 'Unknown')

merged_mhs['gender'] = merged_mhs['gender'].str.replace("afab non-binary", 'Non-Binary')
merged_mhs['gender'] = merged_mhs['gender'].str.replace("non-binary", 'Non-Binary')
merged_mhs['gender'] = merged_mhs['gender'].str.replace("Non-binary/Agender", 'Non-Binary')
merged_mhs['gender'] = merged_mhs['gender'].str.replace("Non-binary", 'Non-Binary')


merged_mhs['gender'] = merged_mhs['gender'].str.replace("female", 'Female')
merged_mhs['gender'] = merged_mhs['gender'].str.replace("Female (cis)", 'Female')
merged_mhs['gender'] = merged_mhs['gender'].str.replace("FEMALE", 'Female')
merged_mhs['gender'] = merged_mhs['gender'].str.replace("Female, cis-gendered", 'Female')
merged_mhs['gender'] = merged_mhs['gender'].str.replace("Woman", 'Female')
merged_mhs['gender'] = merged_mhs['gender'].str.replace("woman", 'Female')
merged_mhs['gender'] = merged_mhs['gender'].str.replace("female, she/her", 'Female')
merged_mhs['gender'] = merged_mhs['gender'].str.replace("Female, she/her", 'Female')
merged_mhs['gender'] = merged_mhs['gender'].str.replace("f", 'Female')
merged_mhs['gender'] = merged_mhs['gender'].str.replace("F", 'Female')
merged_mhs['gender'] = merged_mhs['gender'].str.replace("Femaleemale", 'Female')

merged_mhs['gender'] = merged_mhs['gender'].str.replace("mostly male", 'Male')
merged_mhs['gender'] = merged_mhs['gender'].str.replace("cisgender male", 'Male')
merged_mhs['gender'] = merged_mhs['gender'].str.replace("MAle", 'Male')
merged_mhs['gender'] = merged_mhs['gender'].str.replace("MALE", 'Male')
merged_mhs['gender'] = merged_mhs['gender'].str.replace("Masculine", 'Male')
merged_mhs['gender'] = merged_mhs['gender'].str.replace("male/he/him", 'Male')
merged_mhs['gender'] = merged_mhs['gender'].str.replace('Queer', 'Male')
merged_mhs['gender'] = merged_mhs['gender'].str.replace('varón', 'Male')
merged_mhs['gender'] = merged_mhs['gender'].str.replace("mail", 'Male')
merged_mhs['gender'] = merged_mhs['gender'].str.replace('man', 'Male')
merged_mhs['gender'] = merged_mhs['gender'].str.replace('Cis male', 'Male')
merged_mhs['gender'] = merged_mhs['gender'].str.replace("cis-het male", 'Male')
merged_mhs['gender'] = merged_mhs['gender'].str.replace("cis male", 'Male')
merged_mhs['gender'] = merged_mhs['gender'].str.replace('Cis Male', 'Male')
merged_mhs['gender'] = merged_mhs['gender'].str.replace('dude', 'Male')
merged_mhs['gender'] = merged_mhs['gender'].str.replace('homem cis', 'Male')
merged_mhs['gender'] = merged_mhs['gender'].str.replace("male", 'Male')
merged_mhs['gender'] = merged_mhs['gender'].str.replace("FeMale", 'Female')
merged_mhs['gender'] = merged_mhs['gender'].str.replace("M", 'Male')
merged_mhs['gender'] = merged_mhs['gender'].str.replace("Maleale", 'Male')
merged_mhs['gender'] = merged_mhs['gender'].str.replace("m", 'Male')
merged_mhs['gender'] = merged_mhs['gender'].str.replace("FeMaleale", 'Female')

merged_mhs['gender'] = merged_mhs['gender'].str.replace("b", 'Unknown')
merged_mhs['gender'] = merged_mhs['gender'].str.replace("nan", 'Unknown')

merged_mhs['disorders'] = merged_mhs['disorders'].str.replace("AnxietyDisorder(Generalized, Social, Phobia, etc)","Anxiety Disorder")
merged_mhs['disorders'] = merged_mhs['disorders'].str.replace("MoodDisorder(Depression, BipolarDisorder, etc)","Mood Disorder")
merged_mhs['disorders'] = merged_mhs['disorders'].str.replace("PsychoticDisorder(Schizophrenia, Schizoaffective, etc)","Psychotic Disorder")
merged_mhs['disorders'] = merged_mhs['disorders'].str.replace("EatingDisorder(Anorexia, Bulimia, etc)","Eating Disorder")
merged_mhs['disorders'] = merged_mhs['disorders'].str.replace("AttentionDeficitHyperactivityDisorder","ADHD")
merged_mhs['disorders'] = merged_mhs['disorders'].str.replace("PersonalityDisorder(Borderline, Antisocial, Paranoid, etc)","Personality Disorder")
merged_mhs['disorders'] = merged_mhs['disorders'].str.replace("Obsessive-CompulsiveDisorder","OCD")
merged_mhs['disorders'] = merged_mhs['disorders'].str.replace("Post-traumaticStressDisorder","PTSD")
merged_mhs['disorders'] = merged_mhs['disorders'].str.replace("StressResponseSyndromes","Stress Response Syndromes")
merged_mhs['disorders'] = merged_mhs['disorders'].str.replace("DissociativeDisorder","Dissociative Disorder")
merged_mhs['disorders'] = merged_mhs['disorders'].str.replace("SubstanceUseDisorder","Substance Use Disorder")
merged_mhs['disorders'] = merged_mhs['disorders'].str.replace("AddictiveDisorder","Addiction")
merged_mhs['disorders'] = merged_mhs['disorders'].str.replace("AutismSpectrumDisorder","Autism Spectrum Disorder")
merged_mhs['disorders'] = merged_mhs['disorders'].str.replace("Autismspectrumdisorder","Autism Spectrum Disorder")
merged_mhs['disorders'] = merged_mhs['disorders'].str.replace("Notsure.MaybeamixofA, B, H","Not Sure")

merged_mhs['disorders'] = merged_mhs['disorders'].str.split('|')
merged_mhs = merged_mhs.explode('disorders', ignore_index=True)

# %%
merged_mhs_unique_vals={}
colnames=[]

def unique(list):
    unique_list = []
    for val in list:
        if val not in unique_list:
            unique_list.append(val)
    return unique_list

def countX(lst, x):
    count = 0
    for ele in lst:
        if (ele == x):
            count = count + 1
    return count

count=1
column_names = merged_mhs.columns.tolist()

while count < len(column_names):
    mylist = merged_mhs[column_names[count]].tolist()
    unique_lst = unique(mylist)
    merged_mhs_unique_vals[column_names_2023[count]] = unique_lst
    count=count+1

merged_mhs_unique_vals
# Out:
# {'country-live': ['United States of America',
#   'Russia',
#   'India',
#   'Canada',
#   'Japan',
#   'Ireland',
#   'Turkey',
#   'Australia',
#   'Mongolia',
#   'United Kingdom',
#   'Cameroon',
#   'Pakistan',
#   'Brazil',
#   'Philippines',
#   'Sri Lanka',
#   'Poland',
#   'Taiwan',
#   'Indonesia',
#   'Germany',
#   'Netherlands',
#   'Chile',
#   'Portugal',
#   'South Africa',
#   'Spain',
#   'Sweden',
#   'Serbia',
#   'Egypt',
#   'Ukraine',
#   'Iceland',
#   'Colombia',
#   'Malaysia',
#   'France',
#   'Bangladesh',
#   'Italy',
#   'Belarus',
#   'Macedonia',
#   'Slovenia',
#   'Albania',
#   'Austria',
#   'Kenya',
#   'Sao Tome and Principe',
#   'Vietnam',
#   'Switzerland',
#   'Finland',
#   'Nigeria',
#   'Bulgaria',
#   'Estonia',
#   'Israel',
#   'Greece',
#   'China',
#   'Argentina',
#   'Bosnia and Herzegovina',
#   'Jordan',
#   'Belgium',
#   'Lithuania',
#   'Somalia',
#   'Romania',
#   'Peru',
#   'New Zealand',
#   'Panama',
#   'Uruguay',
#   'Mexico',
#   'Aruba',
#   'Denmark',
#   'Kazakhstan'],
#  'race': ['White', 'Unknown', 'Asian', 'Multi', 'Black or African American'],
#  'gender': ['Male', 'Female', 'Unknown', 'Non-Binary'],
#  'age': ['45',
#   '24',
#   '46',
#   '25',
#   '5',
#   '1',
#   '35',
#   '34',
#   '23',
#   '42',
#   '54',
#   '40',
#   '36',
#   '30',
#   '22',
#   '21',
#   '63',
#   '20',
#   '44',
#   '26',
#   '32',
#   '33',
#   '38',
#   '27',
#   '39',
#   '50',
#   '28',
#   '41',
#   '29',
#   '58',
#   '48',
#   '37',
#   '31',
#   '59',
#   '53',
#   '62',
#   '47',
#   '52',
#   '43',
#   '19',
#   '51',
#   '11',
#   '223',
#   '57',
#   '49',
#   '2',
#   '65',
#   '60',
#   '56',
#   '61',
#   '55',
#   '76'],
#  'anxiety-disorder': ['',
#   'Anxiety Disorder',
#   'Mood Disorder',
#   'Psychotic Disorder',
#   'Eating Disorder',
#   'ADHD',
#   'Personality Disorder',
#   'OCD',
#   'PTSD',
#   'Stress Response Syndromes',
#   'Dissociative Disorder',
#   'Substance Use Disorder',
#   'Addiction',
#   'Autism Spectrum Disorder',
#   'Not Sure']}

# %%
merged_mhs
# Out:
#       year              country-live                       race      gender  \
# 0     2020  United States of America                      White        Male
# 1     2020                    Russia                    Unknown      Female
# 2     2020                    Russia                    Unknown      Female
# 3     2020                     India                    Unknown        Male
# 4     2020                    Canada                    Unknown      Female
# 5     2020                    Canada                    Unknown      Female
# 6     2020  United States of America                      Asian      Female
# 7     2020                     Japan                    Unknown     Unknown
# 8     2020                     Japan                    Unknown     Unknown
# 9     2020                     Japan                    Unknown     Unknown
# 10    2020                     Japan                    Unknown     Unknown
# 11    2020                     Japan                    Unknown     Unknown
# 12    2020                     Japan                    Unknown     Unknown
# 13    2020                     Japan                    Unknown     Unknown
# 14    2020                     Japan                    Unknown     Unknown
# 15    2020                     Japan                    Unknown     Unknown
# 16    2020                     Japan                    Unknown     Unknown
# 17    2020                     Japan                    Unknown     Unknown
# 18    2020                     Japan                    Unknown     Unknown
# 19    2020                     Japan                    Unknown     Unknown
# 20    2020  United States of America                      White        Male
# 21    2020  United States of America                      White        Male
# 22    2020  United States of America                      White        Male
# 23    2020  United States of America                      White        Male
# 24    2020  United States of America                      White        Male
# 25    2020                   Ireland                    Unknown      Female
# 26    2020                    Turkey                    Unknown      Female
# 27    2020  United States of America                      White      Female
# 28    2020  United States of America                      White      Female
# 29    2020  United States of America                      White      Female
# 30    2020  United States of America                      White      Female
# 31    2020  United States of America                      White      Female
# 32    2020  United States of America                      White      Female
# 33    2020  United States of America                      White      Female
# 34    2020  United States of America                      White        Male
# 35    2020  United States of America                      White        Male
# 36    2020                    Canada                    Unknown      Female
# 37    2020  United States of America                      White      Female
# 38    2020  United States of America                      White      Female
# 39    2020  United States of America                      White      Female
# 40    2020  United States of America                      White      Female
# 41    2020                 Australia                    Unknown        Male
# 42    2020                 Australia                    Unknown        Male
# 43    2020                  Mongolia                    Unknown        Male
# 44    2020                  Mongolia                    Unknown        Male
# 45    2020                  Mongolia                    Unknown        Male
# 46    2020                  Mongolia                    Unknown        Male
# 47    2020                  Mongolia                    Unknown        Male
# 202   2020                     India                    Unknown        Male
# 203   2020                     India                    Unknown        Male
# 204   2020                    Canada                    Unknown      Female
# 205   2020                    Canada                    Unknown      Female
# 206   2020                    Canada                    Unknown      Female
# 207   2020                    Canada                    Unknown      Female
# 208   2020                    Sweden                    Unknown        Male
# 209   2020  United States of America                      White      Female
# 210   2020  United States of America                      White        Male
# 211   2020  United States of America                      White        Male
# 212   2020  United States of America                      White        Male
# 213   2020  United States of America                      White      Female
# 214   2020  United States of America                      White      Female
# 215   2020  United States of America                      White      Female
# 216   2020                    Sweden                    Unknown        Male
# 217   2020                    Sweden                    Unknown        Male
# 218   2020                    Sweden                    Unknown        Male
# 219   2020                    Canada                    Unknown        Male
# 220   2020            United Kingdom                    Unknown        Male
# 221   2020            United Kingdom                    Unknown        Male
# 222   2020            United Kingdom                    Unknown        Male
# 223   2020                  Mongolia                    Unknown      Female
# 224   2020                  Mongolia                    Unknown      Female
# 225   2020  United States of America                      White        Male
# 226   2020  United States of America                      White        Male
# 227   2020  United States of America                      White        Male
# 228   2020  United States of America                      White      Female
# 229   2020  United States of America                      White      Female
# 230   2020  United States of America                      White      Female
# 231   2020  United States of America                      White      Female
# 232   2020                     India                    Unknown        Male
# 233   2020                     India                    Unknown      Female
# 234   2020                    Serbia                    Unknown      Female
# 235   2020  United States of America                      White        Male
# 236   2020  United States of America                      White        Male
# 237   2020  United States of America                      Asian      Female
# 238   2020  United States of America                      Asian      Female
# 239   2020  United States of America                      Asian      Female
# 240   2020                   Germany                    Unknown        Male
# 241   2020                     India                    Unknown        Male
# 242   2020  United States of America                      White        Male
# 243   2020  United States of America                      White        Male
# 244   2020  United States of America                      White        Male
# 245   2020                     India                    Unknown        Male
# 246   2020                    Brazil                    Unknown      Female
# 247   2020  United States of America                      White        Male
# 248   2020                     Spain                    Unknown        Male
# 249   2020                     Spain                    Unknown        Male
# 250   2020                     Spain                    Unknown        Male
# 251   2020                     Spain                    Unknown        Male
# 252   2020  United States of America                      White        Male
# 253   2020                     Egypt                    Unknown        Male
# 254   2020  United States of America                      Asian      Female
# 255   2020  United States of America                      Asian      Female
# 256   2020  United States of America                      White        Male
# 257   2020  United States of America                      White        Male
# 258   2020  United States of America                      White        Male
# 259   2020                     India                    Unknown      Female
# 260   2020  United States of America                      White      Female
# 261   2020  United States of America                      White      Female
# 262   2020                     India                    Unknown      Female
# 263   2020                   Germany                    Unknown        Male
# 264   2020  United States of America                      Asian        Male
# 265   2020  United States of America                      White      Female
# 266   2020  United States of America                      White      Female
# 267   2020  United States of America                      White      Female
# 268   2020  United States of America                      White        Male
# 269   2020  United States of America                      White        Male
# 270   2020  United States of America                      White        Male
# 271   2020  United States of America                      White        Male
# 272   2020  United States of America                      White        Male
# 273   2020                     India                    Unknown        Male
# 274   2020                     India                    Unknown        Male
# 275   2020                     India                    Unknown        Male
# 276   2020                     India                    Unknown        Male
# 277   2020                     India                    Unknown        Male
# 278   2020                     India                    Unknown      Female
# 279   2020                    Brazil                    Unknown        Male
# 280   2020               Netherlands                    Unknown        Male
# 281   2020               Netherlands                    Unknown        Male
# 282   2020               Netherlands                    Unknown        Male
# 283   2020                   Ukraine                    Unknown        Male
# 284   2020                   Ukraine                    Unknown        Male
# 285   2020                   Ukraine                    Unknown        Male
# 286   2020                   Iceland                    Unknown        Male
# 287   2020                   Iceland                    Unknown        Male
# 288   2020  United States of America                      White        Male
# 289   2020  United States of America                      White        Male
# 290   2020  United States of America                      White        Male
# 291   2020  United States of America                      White        Male
# 292   2020                     Spain                    Unknown      Female
# 293   2020                  Colombia                    Unknown        Male
# 294   2020                  Colombia                    Unknown        Male
# 295   2020                  Colombia                    Unknown        Male
# 296   2020               Netherlands                    Unknown        Male
# 297   2020               Netherlands                    Unknown        Male
# 298   2020               Philippines                    Unknown      Female
# 299   2020  United States of America  Black or African American      Female
# 300   2020  United States of America  Black or African American      Female
# 301   2020  United States of America  Black or African American      Female
# 302   2020  United States of America  Black or African American      Female
# 303   2020  United States of America                      Asian        Male
# 304   2020                   Germany                    Unknown        Male
# 305   2020                   Germany                    Unknown        Male
# 306   2020                   Germany                    Unknown        Male
# 307   2020  United States of America                      White        Male
# 308   2020  United States of America                      Asian      Female
# 309   2020                     India                    Unknown      Female
# 310   2020                     India                    Unknown        Male
# 311   2020                     India                    Unknown        Male
# 312   2020                    Brazil                    Unknown        Male
# 313   2020                    Brazil                    Unknown        Male
# 314   2020                    Brazil                    Unknown        Male
# 315   2020                    Brazil                    Unknown        Male
# 316   2020                    Brazil                    Unknown        Male
# 317   2020                  Malaysia                    Unknown      Female
# 318   2020  United States of America                      White      Female
# 319   2020  United States of America                      White      Female
# 320   2020  United States of America                      White      Female
# 321   2020                 Indonesia                    Unknown      Female
# 322   2020              South Africa                    Unknown        Male
# 323   2020              South Africa                    Unknown        Male
# 324   2020              South Africa                    Unknown        Male
# 325   2020              South Africa                    Unknown        Male
# 326   2020                    Poland                    Unknown      Female
# 327   2020                    Poland                    Unknown      Female
# 328   2020                     India                    Unknown        Male
# 329   2020                     India                    Unknown      Female
# 330   2020                     India                    Unknown      Female
# 331   2020                     India                    Unknown      Female
# 332   2020                     India                    Unknown      Female
# 333   2020  United States of America                      White      Female
# 334   2020  United States of America                      White      Female
# 335   2020  United States of America                      White      Female
# 336   2020            United Kingdom                    Unknown        Male
# 337   2020            United Kingdom                    Unknown        Male
# 338   2020            United Kingdom                    Unknown        Male
# 339   2020  United States of America                      White        Male
# 340   2020  United States of America                      White        Male
# 341   2020                     India                    Unknown        Male
# 342   2020                     India                    Unknown        Male
# 343   2020                     India                    Unknown        Male
# 344   2020                     India                    Unknown        Male
# 345   2020  United States of America                      White      Female
# 346   2020  United States of America                      White        Male
# 347   2020  United States of America                      White        Male
# 348   2020                    Turkey                    Unknown        Male
# 349   2020                     Spain                    Unknown        Male
# 350   2020                     Spain                    Unknown        Male
# 351   2020                     Spain                    Unknown        Male
# 352   2020                     Spain                    Unknown        Male
# 353   2020  United States of America                      White        Male
# 354   2020  United States of America                      White        Male
# 355   2020            United Kingdom                    Unknown        Male
# 356   2020            United Kingdom                    Unknown        Male
# 357   2020  United States of America                      White      Female
# 358   2020                 Sri Lanka                    Unknown      Female
# 359   2020                 Australia                    Unknown        Male
# 360   2020                 Australia                    Unknown        Male
# 361   2020                 Australia                    Unknown        Male
# 362   2020                 Australia                    Unknown        Male
# 363   2020                    France                    Unknown      Female
# 364   2020                Bangladesh                    Unknown        Male
# 365   2020  United States of America                      Asian      Female
# 366   2020                    Canada                    Unknown        Male
# 367   2020                    Canada                    Unknown        Male
# 368   2020                    Canada                    Unknown        Male
# 369   2020                   Ireland                    Unknown        Male
# 370   2020  United States of America                      White        Male
# 371   2020  United States of America                      White        Male
# 372   2020                    Canada                    Unknown        Male
# 373   2020  United States of America                      White        Male
# 374   2020  United States of America                      White        Male
# 375   2020  United States of America                      White        Male
# 376   2020                     India                    Unknown        Male
# 377   2020                    France                    Unknown      Female
# 378   2020  United States of America                      White        Male
# 379   2020  United States of America                      White        Male
# 380   2020  United States of America                      White        Male
# 381   2020            United Kingdom                    Unknown        Male
# 382   2020            United Kingdom                    Unknown      Female
# 383   2020            United Kingdom                    Unknown      Female
# 384   2020            United Kingdom                    Unknown      Female
# 385   2020                     India                    Unknown        Male
# 386   2020  United States of America                      Asian        Male
# 387   2020               Philippines                    Unknown      Female
# 388   2020               Philippines                    Unknown      Female
# 389   2020               Philippines                    Unknown      Female
# 390   2020               Philippines                    Unknown      Female
# 391   2020  United States of America                      White        Male
# 392   2020  United States of America                      White        Male
# 393   2020                    Canada                    Unknown        Male
# 394   2020                    Canada                    Unknown        Male
# 395   2020                    Canada                    Unknown        Male
# 396   2020                    Canada                    Unknown        Male
# 397   2020               Netherlands                    Unknown        Male
# 398   2021  United States of America                      White      Female
# 399   2021  United States of America                      White      Female
# 400   2021  United States of America                      White      Female
# 401   2021                    Brazil                    Unknown        Male
# 402   2021                    Brazil                    Unknown        Male
# 403   2021                     Italy                    Unknown        Male
# 404   2021                    Canada                    Unknown      Female
# 405   2021  United States of America                      Multi      Female
# 406   2021  United States of America                      Asian      Female
# 407   2021                   Germany                    Unknown      Female
# 408   2021                     India                    Unknown      Female
# 409   2021                   Belarus                    Unknown      Female
# 410   2021                   Germany                    Unknown        Male
# 411   2021                     India                    Unknown        Male
# 412   2021                   Germany                    Unknown      Female
# 413   2021                 Macedonia                    Unknown      Female
# 414   2021                 Macedonia                    Unknown        Male
# 415   2021                 Macedonia                    Unknown        Male
# 416   2021                 Macedonia                    Unknown        Male
# 417   2021                 Macedonia                    Unknown      Female
# 418   2021                  Slovenia                    Unknown      Female
# 419   2021                   Albania                    Unknown        Male
# 420   2021                 Macedonia                    Unknown        Male
# 421   2021                  Slovenia                    Unknown      Female
# 422   2021                  Slovenia                    Unknown      Female
# 423   2021                  Slovenia                    Unknown      Female
# 424   2021                  Slovenia                    Unknown      Female
# 425   2021                  Slovenia                    Unknown      Female
# 426   2021                  Slovenia                    Unknown      Female
# 427   2021                  Slovenia                    Unknown      Female
# 428   2021                  Slovenia                    Unknown        Male
# 584   2021  United States of America                      Asian      Female
# 585   2021  United States of America                      Asian      Female
# 586   2021  United States of America                      Asian      Female
# 587   2021                    Canada                    Unknown        Male
# 588   2021                    Canada                    Unknown        Male
# 589   2021                    Canada                    Unknown        Male
# 590   2021                    Canada                    Unknown        Male
# 591   2021                    Canada                    Unknown        Male
# 592   2021                Bangladesh                    Unknown        Male
# 593   2021                     India                    Unknown        Male
# 594   2021  United States of America                      White        Male
# 595   2021  United States of America                      White        Male
# 596   2021  United States of America                      White        Male
# 597   2021                     India                    Unknown      Female
# 598   2021  United States of America                      White        Male
# 599   2021  United States of America                      White        Male
# 600   2021  United States of America                      White        Male
# 601   2021  United States of America                      White      Female
# 602   2021  United States of America                      White      Female
# 603   2021  United States of America                      White      Female
# 604   2021            United Kingdom                    Unknown      Female
# 605   2021            United Kingdom                    Unknown      Female
# ...
# 594    51           Anxiety Disorder
# 595    51              Mood Disorder
# 596    51
# 597    21
# 598    38              Mood Disorder
# 599    38                       ADHD
# 600    38
# 601    31              Mood Disorder
# 602    31     Substance Use Disorder
# 603    31
# 604    24              Mood Disorder
# 605    24            Eating Disorder
# 606    24
# 607    29              Mood Disorder
# 608    29
# 609    27              Mood Disorder
# 610    27
# 611    25
# 612    47           Anxiety Disorder
# 613    47              Mood Disorder
# 614    47                       ADHD
# 615    47                       PTSD
# 616    47
# 617    30           Anxiety Disorder
# 618    30              Mood Disorder
# 619    30                       ADHD
# 620    30                       PTSD
# 621    30  Stress Response Syndromes
# 622    30                  Addiction
# 623    30
# 624    33              Mood Disorder
# 625    33                       ADHD
# 626    33
# 627    23   Autism Spectrum Disorder
# 628    23
# 629    37           Anxiety Disorder
# 630    37              Mood Disorder
# 631    37
# 632    30           Anxiety Disorder
# 633    30              Mood Disorder
# 634    30                        OCD
# 635    30
# 636    36           Anxiety Disorder
# 637    36                        OCD
# 638    36                       PTSD
# 639    36                  Addiction
# 640    36
# 641    42
# 642    40
# 643    23
# 644    45              Mood Disorder
# 645    45                       ADHD
# 646    45                  Addiction
# 647    45
# 648    30
# 649    34
# 650    45           Anxiety Disorder
# 651    45              Mood Disorder
# 652    45
# 653    30           Anxiety Disorder
# 654    30              Mood Disorder
# 655    30            Eating Disorder
# 656    30
# 657    22
# 658    28
# 659    37           Anxiety Disorder
# 660    37
# 661    23
# 662    35           Anxiety Disorder
# 663    35
# 664    34
# 665    46
# 666    33
# 667    33              Mood Disorder
# 668    33
# 669    49
# 670    28
# 671    26
# 672    38
# 673    23              Mood Disorder
# 674    23                        OCD
# 675    23
# 676    43                       ADHD
# 677    43
# 678    38              Mood Disorder
# 679    38
# 680    35           Anxiety Disorder
# 681    35
# 682    33           Anxiety Disorder
# 683    33              Mood Disorder
# 684    33                       ADHD
# 685    33
# 686    26
# 687    29
# 688    45           Anxiety Disorder
# 689    45              Mood Disorder
# 690    45
# 691    34
# 692    35       Personality Disorder
# 693    35
# 694    20              Mood Disorder
# 695    20            Eating Disorder
# 696    20
# 697    34
# 698    32                       ADHD
# 699    32
# 700    48
# 701    32                       ADHD
# 702    32   Autism Spectrum Disorder
# 703    36           Anxiety Disorder
# 704    36                       ADHD
# 705    36     Substance Use Disorder
# 706    36
# 707    50           Anxiety Disorder
# 708    50
# 709    23           Anxiety Disorder
# 710    23              Mood Disorder
# 711    23                       PTSD
# 712    23      Dissociative Disorder
# 713    23
# 714    25           Anxiety Disorder
# 715    25              Mood Disorder
# 716    25
# 717    23
# 718    43
# 719    53
# 720    27           Anxiety Disorder
# 721    27              Mood Disorder
# 722    27                       ADHD
# 723    27
# 724    45
# 725    44
# 726    39              Mood Disorder
# 727    39
# 728    23           Anxiety Disorder
# 729    23              Mood Disorder
# 730    23
# 731    34              Mood Disorder
# 732    34                       ADHD
# 733    34
# 734    29
# 735    22
# 736    30           Anxiety Disorder
# 737    30              Mood Disorder
# 738    30
# 739    45              Mood Disorder
# 740    45                       ADHD
# 741    45
# 742    33
# 743    44                   Not Sure
# 744    44
# 745    50           Anxiety Disorder
# 746    50              Mood Disorder
# 747    50                       ADHD
# 748    50                        OCD
# 749    50
# 750    22
# 751    30           Anxiety Disorder
# 752    30              Mood Disorder
# 753    30         Psychotic Disorder
# 754    30            Eating Disorder
# 755    30                       ADHD
# 756    30                       PTSD
# 757    30      Dissociative Disorder
# 758    30     Substance Use Disorder
# 759    30                  Addiction
# 760    30
# 761    30
# 762    34           Anxiety Disorder
# 763    34                       ADHD
# 764    34
# 765     2           Anxiety Disorder
# 766     2              Mood Disorder
# 767     2      Dissociative Disorder
# 768     2
# 769    48
# 770    22  Stress Response Syndromes
# 771    22
# 772    38
# 773    45
# 774    36              Mood Disorder
# 775    36
# 776    65
# 777    35
# 778    41
# 779    46              Mood Disorder
# 780    46                       ADHD
# 781    46
# 782    45  Stress Response Syndromes
# 783    45
# 784    36           Anxiety Disorder
# 785    36              Mood Disorder
# 786    36       Personality Disorder
# 787    36                       PTSD
# 788    36
# 789    29
# 790    30
# 791    29
# 792    39
# 793    22              Mood Disorder
# 794    22
# 795    47              Mood Disorder
# 796    47                       PTSD
# 797    47
# 798    26           Anxiety Disorder
# 799    26              Mood Disorder
# 800    26
# 801    38
# 802    49                       PTSD
# 803    49
# 804    37
# 805    34
# 806    43           Anxiety Disorder
# 807    43              Mood Disorder
# 808    43       Personality Disorder
# 809    43  Stress Response Syndromes
# 810    43
# 811    47           Anxiety Disorder
# 812    47              Mood Disorder
# 813    47
# 814    33
# 815    21
# 816    59
# 817    51
# 818    60
# 819    47
# 820    56           Anxiety Disorder
# 821    56              Mood Disorder
# 822    56  Stress Response Syndromes
# 823    56
# 824    40
# 825    38
# 826    50
# 827    20
# 828    35
# 829    29
# 830    39
# 831    49
# 832    45
# 833    50
# 834    44              Mood Disorder
# 835    44
# 836    59
# 837    43
# 838    42           Anxiety Disorder
# 839    42              Mood Disorder
# 840    42         Psychotic Disorder
# 841    42                       ADHD
# 842    42       Personality Disorder
# 843    42                       PTSD
# 844    42      Dissociative Disorder
# 845    42
# 846    41
# 847    38              Mood Disorder
# 848    38
# 849    33
# 850    50           Anxiety Disorder
# 851    50              Mood Disorder
# 852    50
# 853    28           Anxiety Disorder
# 854    28              Mood Disorder
# 855    28                       PTSD
# 856    28
# 857    40
# 858    58
# 859    65
# 860    36
# 861    35              Mood Disorder
# 862    35  Stress Response Syndromes
# 863    35     Substance Use Disorder
# 864    35                  Addiction
# 865    35
# 866    61           Anxiety Disorder
# 867    61              Mood Disorder
# 868    61                       ADHD
# 869    61                        OCD
# 870    61
# 871    50
# 872    40              Mood Disorder
# 873    40                       ADHD
# 874    40
# 875    37
# 876    32
# 877    46              Mood Disorder
# 878    46
# 879    36
# 880    23           Anxiety Disorder
# 881    23              Mood Disorder
# 882    23                       PTSD
# 883    23  Stress Response Syndromes
# 884    23
# 885    39
# 886    28           Anxiety Disorder
# 887    28              Mood Disorder
# 888    28                       ADHD
# 889    28                        OCD
# 890    28
# 891    44
# 892    36
# 893    32
# 894    55           Anxiety Disorder
# 895    55              Mood Disorder
# 896    55                       ADHD
# 897    55     Substance Use Disorder
# 898    55                  Addiction
# 899    55
# 900    42
# 901    26
# 902    61                       ADHD
# 903    61
# 904    56
# 905    63
# 906    60
# 907    46
# 908    43           Anxiety Disorder
# 909    43
# 910    39
# 911    44           Anxiety Disorder
# 912    44              Mood Disorder
# 913    44                       ADHD
# 914    44
# 915    32           Anxiety Disorder
# 916    32
# 917    35
# 918    48
# 919    45
# 920    46
# 921    31              Mood Disorder
# 922    31
# 923    41
# 924    38
# 925    39
# 926    51
# 927    43
# 928    35
# 929    37
# 930    31           Anxiety Disorder
# 931    31
# 932    39
# 933    37
# 934    37           Anxiety Disorder
# 935    37              Mood Disorder
# 936    37                       PTSD
# 937    37     Substance Use Disorder
# 938    37
# 939    76
# 940    47
# 941    41
# 942    58
# 943    46
# 944    53
# 945    30           Anxiety Disorder
# 946    30              Mood Disorder
# 947    30                        OCD
# 948    30
# 949    55
# 950    36           Anxiety Disorder
# 951    36                        OCD
# 952    36  Stress Response Syndromes
# 953    36
# 954    44
# 955    58
# 956    45
# 957    46
# 958    33
# 959    61
# 960    24
# 961    46
# 962    33                       PTSD
# 963    33
# 964    57
# 965    31           Anxiety Disorder
# 966    31
# 967    40
# 968    38
# 969    38           Anxiety Disorder
# 970    38
# 971    31
# 972    40
# 973    23
# 974    21           Anxiety Disorder
# 975    21                       ADHD
# 976    21                  Addiction
# 977    21
# 978    32           Anxiety Disorder
# 979    32
# 980    40           Anxiety Disorder
# 981    40              Mood Disorder
# 982    40                       ADHD
# 983    40                       PTSD
# 984    40
# 985    36           Anxiety Disorder
# 986    36                  Addiction
# 987    36
# 988    44           Anxiety Disorder
# 989    44              Mood Disorder
# 990    44                       ADHD
# 991    44                       PTSD
# 992    44
# 993    53           Anxiety Disorder
# 994    53              Mood Disorder
# 995    53
# 996    62              Mood Disorder
# 997    62                       ADHD
# 998    62                        OCD
# 999    62                  Addiction
# 1000   62
# 1001   39           Anxiety Disorder
# 1002   39              Mood Disorder
# 1003   39                       ADHD
# 1004   39
