# %%
import pandas as pd
from prophet import Prophet
import datetime as dt
import numpy as np
# %matplotlib inline
# read resources/2016.csv and set into a mhs_2016 DataFrame
mhs_2016 = pd.read_csv("resources/2016.csv")
display(mhs_2016.head())

# read resources/2017.csv and set into a mhs_2017 DataFrame
mhs_2017 = pd.read_csv("resources/2017.csv")
display(mhs_2017.head())

# read resources/2018.csv and set into a mhs_2018 DataFrame
mhs_2018 = pd.read_csv("resources/2018.csv")
display(mhs_2018.head())

# read resources/2019.csv and set into a mhs_2019 DataFrame
mhs_2019 = pd.read_csv("resources/2019.csv")
display(mhs_2019.head())

# read resources/2020.csv and set into a mhs_2020 DataFrame
mhs_2020 = pd.read_csv("resources/2020.csv")
display(mhs_2020.head())

# read resources/2021.csv and set into a mhs_2021 DataFrame
mhs_2021 = pd.read_csv("resources/2021.csv")
display(mhs_2021.head())

# read resources/2022.csv and set into a mhs_2022 DataFrame
mhs_2022 = pd.read_csv("resources/2022.csv")
display(mhs_2022.head())

# read resources/2023.csv and set into a mhs_2023 DataFrame
mhs_2023 = pd.read_csv("resources/2023.csv")
display(mhs_2023.head())
# Out:
#         #  Are you self-employed?  \
# 0   99999                       0
# 1  100000                       0
# 2  100001                       0
# 3  100002                       1
# 4  100003                       0
#
#   How many employees does your company or organization have?  \
# 0                                             26-100
# 1                                             25-Jun
# 2                                             25-Jun
# 3                                                NaN
# 4                                             25-Jun
#
#    Is your employer primarily a tech company/organization?  \
# 0                                                1.0
# 1                                                1.0
# 2                                                1.0
# 3                                                NaN
# 4                                                0.0
#
#    Is your primary role within your company related to tech/IT?  \
# ...

# %%
merged_df = pd.concat([mhs_2016, mhs_2017, mhs_2018, mhs_2019, mhs_2020, mhs_2021, mhs_2022, mhs_2023])
display(merged_df.head())
# Out:
#    Are you self-employed?  \
# 0                     0.0
# 1                     0.0
# 2                     0.0
# 3                     1.0
# 4                     0.0
#
#   How many employees does your company or organization have?  \
# 0                                             26-100
# 1                                               6-25
# 2                                               6-25
# 3                                                NaN
# 4                                               6-25
#
#   Is your employer primarily a tech company/organization?  \
# 0                                                1.0
# 1                                                1.0
# 2                                                1.0
# 3                                                NaN
# 4                                                0.0
#
#   Is your primary role within your company related to tech/IT?  \
# 0                                                NaN
# ...

# %%
merged_df.describe()
# Out:
#        Are you self-employed?  \
# count             1433.000000
# mean                 0.200279
# std                  0.400349
# min                  0.000000
# 25%                  0.000000
# 50%                  0.000000
# 75%                  0.000000
# max                  1.000000
#
#        Do you have medical coverage (private insurance or state-provided) which includes treatment of  mental health issues?  \
# count                                         287.000000
# mean                                            0.644599
# std                                             0.479471
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             1.000000
# 75%                                             1.000000
# max                                             1.000000
#
#        Do you have previous employers?  \
# count                      1433.000000
# ...

# %%
merged_df
# Out:
#     Are you self-employed?  \
# 0                      0.0
# 1                      0.0
# 2                      0.0
# 3                      1.0
# 4                      0.0
# ..                     ...
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# 5                      NaN
#
#    How many employees does your company or organization have?  \
# 0                                              26-100
# 1                                                6-25
# 2                                                6-25
# 3                                                 NaN
# 4                                                6-25
# ..                                                ...
# 1                                                6-25
# 2                                                 NaN
# 3                                            500-1000
# 4                                                 NaN
# ...

# %%
merged_df.plot()
# Out:
# <Axes: >

# %%
print(list(merged_df.columns))
# Out:
# ['Are you self-employed?', 'How many employees does your company or organization have?', 'Is your employer primarily a tech company/organization?', 'Is your primary role within your company related to tech/IT?', 'Does your employer provide mental health benefits as part of healthcare coverage?', 'Do you know the options for mental health care available under your employer-provided coverage?', 'Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?', 'Does your employer offer resources to learn more about mental health concerns and options for seeking help?', 'Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?', 'If a mental health issue prompted you to request a medical leave from work, asking for that leave would be:', 'Do you think that discussing a mental health disorder with your employer would have negative co
# ...

# %%
column_mapping = {
    'Are you self-employed?': 'self_employed',
    'How many employees does your company or organization have?': 'company_size',
    'Is your employer primarily a tech company/organization?': 'tech_company',
    'Is your primary role within your company related to tech/IT?': 'tech_role',
    'Does your employer provide mental health benefits as part of healthcare coverage?': 'mental_health_benefits',
    'Do you know the options for mental health care available under your employer-provided coverage?': 'aware_of_mental_health_options',
    'Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?': 'discussed_mental_health',
    'Does your employer offer resources to learn more about mental health concerns and options for seeking help?': 'mental_health_resources',
    'Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?': 'anonymity_protection',
    'If a mental health issue prompted you to request a medical leave from work, asking for that leave would be:': 'ease_of_requesting_leave',
    'Do you think that discussing a mental health disorder with your employer would have negative consequences?': 'negative_consequences_mental_health',
    'Do you think that discussing a physical health issue with your employer would have negative consequences?': 'negative_consequences_physical_health',
    'Would you feel comfortable discussing a mental health disorder with your coworkers?': 'comfortable_discussing_mental_health_coworkers',
    'Would you feel comfortable discussing a mental health disorder with your direct supervisor(s)?': 'comfortable_discussing_mental_health_supervisor',
    'Do you feel that your employer takes mental health as seriously as physical health?': 'employer_serious_about_mental_health',
    'Have you heard of or observed negative consequences for co-workers who have been open about mental health issues in your workplace?': 'observed_negative_consequences',
    'Do you have medical coverage (private insurance or state-provided) which includes treatment of \xa0mental health issues?': 'has_medical_coverage',
    'Do you know local or online resources to seek help for a mental health disorder?': 'aware_of_resources',
    'If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to clients or business contacts?': 'reveal_to_clients',
    'If you have revealed a mental health issue to a client or business contact, do you believe this has impacted you negatively?': 'negative_impact_clients',
    'If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to coworkers or employees?': 'reveal_to_coworkers',
    'If you have revealed a mental health issue to a coworker or employee, do you believe this has impacted you negatively?': 'negative_impact_coworkers',
    'Do you believe your productivity is ever affected by a mental health issue?': 'productivity_affected',
    'If yes, what percentage of your work time (time performing primary or secondary job functions) is affected by a mental health issue?': 'percentage_time_affected',
    'Do you have previous employers?': 'previous_employers',
    'Have your previous employers provided mental health benefits?': 'previous_employer_mental_health_benefits',
    'Were you aware of the options for mental health care provided by your previous employers?': 'aware_of_previous_options',
    'Did your previous employers ever formally discuss mental health (as part of a wellness campaign or other official communication)?': 'previous_discussed_mental_health',
    'Did your previous employers provide resources to learn more about mental health issues and how to seek help?': 'previous_resources',
    'Was your anonymity protected if you chose to take advantage of mental health or substance abuse treatment resources with previous employers?': 'previous_anonymity_protection',
    'Do you think that discussing a mental health disorder with previous employers would have negative consequences?': 'previous_negative_consequences_mental_health',
    'Do you think that discussing a physical health issue with previous employers would have negative consequences?': 'previous_negative_consequences_physical_health',
    'Would you have been willing to discuss a mental health issue with your previous co-workers?': 'willing_to_discuss_with_previous_coworkers',
    'Would you have been willing to discuss a mental health issue with your direct supervisor(s)?': 'willing_to_discuss_with_previous_supervisor',
    'Did you feel that your previous employers took mental health as seriously as physical health?': 'previous_serious_about_mental_health',
    'Did you hear of or observe negative consequences for co-workers with mental health issues in your previous workplaces?': 'previous_observed_negative_consequences',
    'Would you be willing to bring up a physical health issue with a potential employer in an interview?': 'willing_to_discuss_physical_health_in_interview',
    'Why or why not?': 'why_not',
    'Would you bring up a mental health issue with a potential employer in an interview?': 'willing_to_discuss_mental_health_in_interview',
    'Why or why not?.1': 'why_not_2',
    'Do you feel that being identified as a person with a mental health issue would hurt your career?': 'career_hurt_by_mental_health',
    'Do you think that team members/co-workers would view you more negatively if they knew you suffered from a mental health issue?': 'negative_view_by_team',
    'How willing would you be to share with friends and family that you have a mental illness?': 'willing_to_share_with_friends_and_family',
    'Have you observed or experienced an unsupportive or badly handled response to a mental health issue in your current or previous workplace?': 'unsupportive_response_observed',
    'Have your observations of how another individual who discussed a mental health disorder made you less likely to reveal a mental health issue yourself in your current workplace?': 'less_likely_to_reveal_due_to_observation',
    'Do you have a family history of mental illness?': 'family_history',
    'Have you had a mental health disorder in the past?': 'past_mental_health_disorder',
    'Do you currently have a mental health disorder?': 'current_mental_health_disorder',
    'If yes, what condition(s) have you been diagnosed with?': 'diagnosed_conditions',
    'If maybe, what condition(s) do you believe you have?': 'believed_conditions',
    'Have you been diagnosed with a mental health condition by a medical professional?': 'professional_diagnosis',
    'If so, what condition(s) were you diagnosed with?': 'conditions_diagnosed',
    'Have you ever sought treatment for a mental health issue from a mental health professional?': 'sought_treatment',
    'If you have a mental health issue, do you feel that it interferes with your work when being treated effectively?': 'interferes_with_work_when_treated',
    'If you have a mental health issue, do you feel that it interferes with your work when NOT being treated effectively?': 'interferes_with_work_when_untreated',
    'What is your age?': 'age',
    'What is your gender?': 'gender',
    'What country do you live in?': 'country_live',
    'What US state or territory do you live in?': 'us_state_live',
    'What country do you work in?': 'country_work',
    'What US state or territory do you work in?': 'us_state_work',
    'Which of the following best describes your work position?': 'work_position',
    'Do you work remotely?': 'remote_work',
    '#': 'number',
    '<strong>Are you self-employed?</strong>': 'self_employed_2',
    'Does your employer provide mental health benefits\xa0as part of healthcare coverage?': 'mental_health_benefits_2',
    'Do you know the options for mental health care available under your employer-provided health coverage?': 'aware_of_employer_health_coverage',
    'Does your employer offer resources to learn more about mental health disorders and options for seeking help?': 'employer_resources',
    'If a mental health issue prompted you to request a medical leave from work, how easy or difficult would it be to ask for that leave?': 'ease_of_requesting_leave_2',
    'Would you feel more comfortable talking to your coworkers about your physical health or your mental health?': 'comfortable_talking_to_coworkers',
    'Would you feel comfortable discussing a mental health issue with your direct supervisor(s)?': 'comfortable_talking_to_supervisor',
    'Have you ever discussed your mental health with your employer?': 'discussed_mental_health_with_employer',
    'Describe the conversation you had with your employer about your mental health, including their reactions and what actions were taken to address your mental health issue/questions.': 'describe_employer_conversation',
    'Would you feel comfortable discussing a mental health issue with your coworkers?': 'comfortable_talking_to_coworkers_2',
    'Have you ever discussed your mental health with coworkers?': 'discussed_mental_health_with_coworkers',
    'Describe the conversation with coworkers you had about your mental health including their reactions.': 'describe_coworker_conversation',
    "Have you ever had a coworker discuss their or another coworker's mental health with you?": 'coworker_discussion',
    'Describe the conversation your coworker had with you about their mental health (please do not use names).': 'describe_coworker_discussion',
    'Overall, how much importance does your employer place on physical health?': 'employer_importance_physical_health',
    'Overall, how much importance does your employer place on mental health?': 'employer_importance_mental_health',
    'Do you have medical coverage (private insurance or state-provided) that includes treatment of mental health disorders?': 'has_mental_health_coverage',
    'Do you know local or online resources to seek help for a mental health issue?': 'aware_of_local_resources',
    '<strong>If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to clients or business contacts?</strong>': 'reveal_to_clients_2',
    'If you have revealed a mental health disorder to a client or business contact, how has this affected you or the relationship?': 'impact_of_revealing_to_clients',
    '<strong>If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to coworkers or employees?</strong>': 'reveal_to_coworkers_2',
    'If you have revealed a mental health disorder to a coworker or employee, how has this impacted you or the relationship?': 'impact_of_revealing_to_coworkers',
    '<strong>Do you have previous employers?</strong>': 'previous_employers_2',
    'Was your employer primarily a tech company/organization?': 'tech_company_previous_employer',
    '<strong>Have your previous employers provided mental health benefits?</strong>': 'previous_mental_health_benefits',
    '<strong>Were you aware of the options for mental health care provided by your previous employers?</strong>': 'aware_of_previous_options_2',
    'Did your previous employers provide resources to learn more about mental health disorders and how to seek help?': 'previous_resources_2',
    'Would you have felt more comfortable talking to your previous employer about your physical health or your mental health?': 'comfortable_talking_to_previous_employer',
    'Would you have been willing to discuss your mental health with your direct supervisor(s)?': 'comfortable_talking_to_previous_supervisor',
    'Did you ever discuss your mental health with your previous employer?': 'discussed_mental_health_with_previous_employer',
    'Describe the conversation you had with your previous employer about your mental health, including their reactions and actions taken to address your mental health issue/questions.': 'describe_previous_employer_conversation',
    '<strong>Would you have been willing to discuss your mental health with your coworkers at previous employers?</strong>': 'comfortable_talking_to_previous_coworkers',
    'Did you ever discuss your mental health with a previous coworker(s)?': 'discussed_mental_health_with_previous_coworkers',
    'Describe the conversation you had with your previous coworkers about your mental health including their reactions.': 'describe_previous_coworker_conversation',
    "Did you ever have a previous coworker discuss their or another coworker's mental health with you?": 'previous_coworker_discussion',
    'Describe the conversation your coworker had with you about their mental health (please do not use names)..1': 'describe_previous_coworker_discussion',
    'Overall, how much importance did your previous employer place on physical health?': 'previous_employer_importance_physical_health',
    'Overall, how much importance did your previous employer place on mental health?': 'previous_employer_importance_mental_health',
    'Have you ever been diagnosed with a mental health disorder?': 'diagnosed_mental_health_disorder',
    'Anxiety Disorder (Generalized, Social, Phobia, etc)': 'anxiety_disorder',
    'Mood Disorder (Depression, Bipolar Disorder, etc)': 'mood_disorder',
    'Psychotic Disorder (Schizophrenia, Schizoaffective, etc)': 'psychotic_disorder',
    'Eating Disorder (Anorexia, Bulimia, etc)': 'eating_disorder',
    'Attention Deficit Hyperactivity Disorder': 'adhd',
    'Personality Disorder (Borderline, Antisocial, Paranoid, etc)': 'personality_disorder',
    'Obsessive-Compulsive Disorder': 'ocd',
    'Post-Traumatic Stress Disorder': 'ptsd',
    'Stress Response Syndromes': 'stress_response',
    'Dissociative Disorder': 'dissociative_disorder',
    'Substance Use Disorder': 'substance_use_disorder',
    'Addictive Disorder': 'addictive_disorder',
    'Other': 'other_mental_health_disorder',
    'Anxiety Disorder (Generalized, Social, Phobia, etc).1': 'anxiety_disorder_2',
    'Mood Disorder (Depression, Bipolar Disorder, etc).1': 'mood_disorder_2',
    'Psychotic Disorder (Schizophrenia, Schizoaffective, etc).1': 'psychotic_disorder_2',
    'Eating Disorder (Anorexia, Bulimia, etc).1': 'eating_disorder_2',
    'Attention Deficit Hyperactivity Disorder.1': 'adhd_2',
    'Personality Disorder (Borderline, Antisocial, Paranoid, etc).1': 'personality_disorder_2',
    'Obsessive-Compulsive Disorder.1': 'ocd_2',
    'Post-traumatic Stress Disorder': 'ptsd_2',
    'Stress Response Syndromes.1': 'stress_response_2',
    'Dissociative Disorder.1': 'dissociative_disorder_2',
    'Substance Use Disorder.1': 'substance_use_disorder_2',
    'Addictive Disorder.1': 'addictive_disorder_2',
    'Other.1': 'other_mental_health_disorder_2',
    'Anxiety Disorder (Generalized, Social, Phobia, etc).2': 'anxiety_disorder_3',
    'Mood Disorder (Depression, Bipolar Disorder, etc).2': 'mood_disorder_3',
    'Psychotic Disorder (Schizophrenia, Schizoaffective, etc).2': 'psychotic_disorder_3',
    'Eating Disorder (Anorexia, Bulimia, etc).2': 'eating_disorder_3',
    'Attention Deficit Hyperactivity Disorder.2': 'adhd_3',
    'Personality Disorder (Borderline, Antisocial, Paranoid, etc).2': 'personality_disorder_3',
    'Obsessive-Compulsive Disorder.2': 'ocd_3',
    'Post-traumatic Stress Disorder.1': 'ptsd_3',
    'Stress Response Syndromes.2': 'stress_response_3',
    'Dissociative Disorder.2': 'dissociative_disorder_3',
    'Substance Use Disorder.2': 'substance_use_disorder_3',
    'Addictive Disorder.2': 'addictive_disorder_3',
    'Other.2': 'other_mental_health_disorder_3',
    'Have you ever sought treatment for a mental health disorder from a mental health professional?': 'sought_treatment_2',
    'If you have a mental health disorder, how often do you feel that it interferes with your work <strong>when being treated effectively?</strong>': 'interferes_with_work_when_treated_2',
    'If you have a mental health disorder, how often do you feel that it interferes with your work <strong>when <em>NOT</em> being treated effectively (i.e., when you are experiencing symptoms)?</strong>': 'interferes_with_work_when_untreated_2',
    'Have your observations of how another individual who discussed a mental health issue made you less likely to reveal a mental health issue yourself in your current workplace?': 'less_likely_to_reveal_due_to_observation_2',
    'Would you bring up your mental health with a potential employer in an interview?': 'bring_up_mental_health_in_interview',
    'Are you openly identified at work as a person with a mental health issue?': 'openly_identified_with_mental_health_issue',
    'Has being identified as a person with a mental health issue affected your career?': 'career_impact_due_to_mental_health',
    'How has it affected your career?': 'describe_career_impact',
    'If they knew you suffered from a mental health disorder,\xa0how do you think that team members/co-workers would react?': 'team_reaction_to_mental_health',
    '<strong>Have you observed or experienced an unsupportive or badly handled response to a mental health issue in your current or previous workplace?</strong>': 'observed_unsupportive_response',
    'Describe the circumstances of the badly handled or unsupportive response.': 'describe_unsupportive_response',
    '<strong>Have you observed or experienced supportive or well handled response to a mental health issue in your current or previous workplace?</strong>': 'observed_supportive_response',
    'Describe the circumstances of the supportive or well handled response.': 'describe_supportive_response',
    'Overall, how well do you think the tech industry supports employees with mental health issues?': 'industry_support',
    'Briefly describe what you think the industry as a whole and/or employers could do to improve mental health support for employees.': 'improvement_suggestions',
    'If there is anything else you would like to tell us that has not been covered by the survey questions, please use this space to do so.': 'additional_comments',
    'Would you be willing to talk to one of us more extensively about your experiences with mental health issues in the tech industry? (Note that all interview responses would be used <em>anonymously</em>\xa0and only with your permission.)': 'willing_to_talk_about_experience',
    'What country do you <strong>live</strong> in?': 'country_live_2',
    'What US state or territory do you <strong>live</strong> in?': 'us_state_live_2',
    'What is your race?': 'race',
    'Other.3': 'other_3',
    'What country do you <strong>work</strong> in?': 'country_work_2',
    'What US state or territory do you <strong>work</strong> in?': 'us_state_work_2',
    'Start Date (UTC)': 'start_date',
    'Submit Date (UTC)': 'submit_date',
    'Network ID': 'network_id',
    'If you have a mental health disorder, how often do you feel that it interferes with your work <strong>when</strong> <em><strong>NOT</strong></em><strong> being treated effectively (i.e., when you are experiencing symptoms)?</strong>': 'interferes_with_work_when_untreated_3',
    'If they knew you suffered from a mental health disorder, how do you think that team members/co-workers would react?': 'team_reaction_to_mental_health_2',
    'Would you be willing to talk to one of us more extensively about your experiences with mental health issues in the tech industry? (Note that all interview responses would be used <em>anonymously</em> and only with your permission.)': 'willing_to_talk_about_experience_2',
    '*Are you self-employed?*': 'self_employed_3',
    '*Do you have previous employers?*': 'previous_employers_3',
    'Would you have been willing to discuss your mental health with your coworkers at previous employers?': 'comfortable_talking_to_previous_coworkers_2',
    'Do you *currently* have a mental health disorder?': 'current_mental_health_disorder_2',
    'Have you ever been *diagnosed* with a mental health disorder?': 'diagnosed_mental_health_disorder_2',
    '*What disorder(s) have you been diagnosed with?*': 'diagnosed_conditions_2',
    '*If possibly, what disorder(s) do you believe you have?*': 'believed_conditions_2',
    '*If so, what disorder(s) were you diagnosed with?*': 'conditions_diagnosed_2',
    'If you have a mental health disorder, how often do you feel that it interferes with your work *when being treated effectively?*': 'interferes_with_work_when_treated_3',
    'If you have a mental health disorder, how often do you feel that it interferes with your work *when* _*NOT*_* being treated effectively (i.e., when you are experiencing symptoms)?*': 'interferes_with_work_when_untreated_4',
    'Would you bring up your *mental* health with a potential employer in an interview?': 'bring_up_mental_health_in_interview_2',
    'If they knew you suffered from a mental health disorder, how do you think that your team members/co-workers would react?': 'team_reaction_to_mental_health_3',
    'Have you observed or experienced an *unsupportive or badly handled response* to a mental health issue in your current or previous workplace?': 'observed_unsupportive_response_2',
    'Have you observed or experienced a *supportive or well handled response* to a mental health issue in your current or previous workplace?': 'observed_supportive_response_2',
    'Would you be willing to talk to one of us more extensively about your experiences with mental health issues in the tech industry? (Note that all interview responses would be used _anonymously_ and only with your permission.)': 'willing_to_talk_about_experience_3',
    'What country do you *live* in?': 'country_live_3',
    'What US state or territory do you *live* in?': 'us_state_live_3',
    'What country do you *work* in?': 'country_work_3',
    'What US state or territory do you *work* in?': 'us_state_work_3',
    'Have you been diagnosed with COVID-19?': 'diagnosed_covid',
    'Response Type': 'response_type',
    'Tags': 'tags'
}

# Rename the columns of the DataFrame
merged_df = merged_df.rename(columns=column_mapping)

# Display the updated column names
print(merged_df.columns)
# Out:
# Index(['self_employed', 'company_size', 'tech_company', 'tech_role',
#        'mental_health_benefits', 'aware_of_mental_health_options',
#        'discussed_mental_health', 'mental_health_resources',
#        'anonymity_protection', 'ease_of_requesting_leave',
#        ...
#        'observed_unsupportive_response_2', 'observed_supportive_response_2',
#        'willing_to_talk_about_experience_3', 'country_live_3',
#        'us_state_live_3', 'country_work_3', 'us_state_work_3',
#        'diagnosed_covid', 'response_type', 'tags'],
#       dtype='object', length=193)

# %%
merged_df.head()
# Out:
#    self_employed company_size tech_company tech_role  \
# 0            0.0       26-100          1.0       NaN
# 1            0.0         6-25          1.0       NaN
# 2            0.0         6-25          1.0       NaN
# 3            1.0          NaN          NaN       NaN
# 4            0.0         6-25          0.0       1.0
#
#             mental_health_benefits aware_of_mental_health_options  \
# 0  Not eligible for coverage / N/A                            NaN
# 1                               No                            Yes
# 2                               No                            NaN
# 3                              NaN                            NaN
# 4                              Yes                            Yes
#
#   discussed_mental_health mental_health_resources anonymity_protection  \
# 0                      No                      No         I don't know
# 1                     Yes                     Yes                  Yes
# ...

# %%
print(list(merged_df.columns))
# Out:
# ['self_employed', 'company_size', 'tech_company', 'tech_role', 'mental_health_benefits', 'aware_of_mental_health_options', 'discussed_mental_health', 'mental_health_resources', 'anonymity_protection', 'ease_of_requesting_leave', 'negative_consequences_mental_health', 'negative_consequences_physical_health', 'comfortable_discussing_mental_health_coworkers', 'comfortable_discussing_mental_health_supervisor', 'employer_serious_about_mental_health', 'observed_negative_consequences', 'has_medical_coverage', 'aware_of_resources', 'reveal_to_clients', 'negative_impact_clients', 'reveal_to_coworkers', 'negative_impact_coworkers', 'productivity_affected', 'percentage_time_affected', 'previous_employers', 'previous_employer_mental_health_benefits', 'aware_of_previous_options', 'previous_discussed_mental_health', 'previous_resources', 'previous_anonymity_protection', 'previous_negative_consequences_mental_health', 'previous_negative_consequences_physical_health', 'willing_to_discuss_with_previo
# ...

# %%
total_list=[]

col_list_2016=mhs_2016.columns.tolist()
col_list_2017=mhs_2017.columns.tolist()
col_list_2018=mhs_2018.columns.tolist()
col_list_2019=mhs_2019.columns.tolist()
col_list_2020=mhs_2020.columns.tolist()
col_list_2021=mhs_2021.columns.tolist()
col_list_2022=mhs_2022.columns.tolist()
col_list_2023=mhs_2023.columns.tolist()

for col in col_list_2016:
    total_list.append(col)

for col in col_list_2017:
    total_list.append(col)

for col in col_list_2018:
    total_list.append(col)

for col in col_list_2019:
    total_list.append(col)

for col in col_list_2020:
    total_list.append(col)

for col in col_list_2021:
    total_list.append(col)

for col in col_list_2022:
    total_list.append(col)

for col in col_list_2023:
    total_list.append(col)

# %%
print(len(col_list_2016))
print(len(col_list_2017))
print(len(col_list_2018))
print(len(col_list_2019))
print(len(col_list_2020))
print(len(col_list_2021))
print(len(col_list_2022))
print(len(col_list_2023))
print(len(col_list_2016) + len(col_list_2017) + len(col_list_2018) + len(col_list_2019) + len(col_list_2020) + len(col_list_2021) + len(col_list_2022) + len(col_list_2023))
print(len(total_list))
# Out:
# 63
# 123
# 123
# 82
# 120
# 124
# 126
# 126
# 887
# 887

# %%
total_list.sort()
total_list = list(dict.fromkeys(total_list))
print(len(total_list))
# Out:
# 193

# %%
total_list
# Out:
# ['#',
#  '*Are you self-employed?*',
#  '*Do you have previous employers?*',
#  '*If possibly, what disorder(s) do you believe you have?*',
#  '*If so, what disorder(s) were you diagnosed with?*',
#  '*What disorder(s) have you been diagnosed with?*',
#  '<strong>Are you self-employed?</strong>',
#  '<strong>Do you have previous employers?</strong>',
#  '<strong>Have you observed or experienced an unsupportive or badly handled response to a mental health issue in your current or previous workplace?</strong>',
#  '<strong>Have you observed or experienced supportive or well handled response to a mental health issue in your current or previous workplace?</strong>',
#  '<strong>Have your previous employers provided mental health benefits?</strong>',
#  '<strong>If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to clients or business contacts?</strong>',
# ...

# %%
total_list_df=pd.DataFrame(total_list, columns=["Total_List_Cols"])
col_list_2016_df=pd.DataFrame(col_list_2016, columns=["col_list_2016_Cols"])
col_list_2017_df=pd.DataFrame(col_list_2017, columns=["col_list_2017_Cols"])
col_list_2018_df=pd.DataFrame(col_list_2018, columns=["col_list_2018_Cols"])
col_list_2019_df=pd.DataFrame(col_list_2019, columns=["col_list_2019_Cols"])
col_list_2020_df=pd.DataFrame(col_list_2020, columns=["col_list_2020_Cols"])
col_list_2021_df=pd.DataFrame(col_list_2021, columns=["col_list_2021_Cols"])
col_list_2022_df=pd.DataFrame(col_list_2022, columns=["col_list_2022_Cols"])
col_list_2023_df=pd.DataFrame(col_list_2023, columns=["col_list_2023_Cols"])

# %%
col_list_2020_df.head()
# Out:
#                                   col_list_2020_Cols
# 0                                                  #
# 1                           *Are you self-employed?*
# 2  How many employees does your company or organi...
# 3  Is your employer primarily a tech company/orga...
# 4  Is your primary role within your company relat...

# %%
comp_df=total_list_df.merge(col_list_2016_df, left_on="Total_List_Cols", right_on="col_list_2016_Cols", how="outer")
comp_df=comp_df.merge(col_list_2017_df, left_on="Total_List_Cols", right_on="col_list_2017_Cols", how="outer")
comp_df=comp_df.merge(col_list_2018_df, left_on="Total_List_Cols", right_on="col_list_2018_Cols", how="outer")
comp_df=comp_df.merge(col_list_2019_df, left_on="Total_List_Cols", right_on="col_list_2019_Cols", how="outer")
comp_df=comp_df.merge(col_list_2020_df, left_on="Total_List_Cols", right_on="col_list_2020_Cols", how="outer")
comp_df=comp_df.merge(col_list_2021_df, left_on="Total_List_Cols", right_on="col_list_2021_Cols", how="outer")
comp_df=comp_df.merge(col_list_2022_df, left_on="Total_List_Cols", right_on="col_list_2022_Cols", how="outer")
comp_df=comp_df.merge(col_list_2023_df, left_on="Total_List_Cols", right_on="col_list_2023_Cols", how="outer")

# %%
comp_df
# Out:
#                                        Total_List_Cols  \
# 0                                                    #
# 1                             *Are you self-employed?*
# 2                    *Do you have previous employers?*
# 3    *If possibly, what disorder(s) do you believe ...
# 4    *If so, what disorder(s) were you diagnosed wi...
# ..                                                 ...
# 188  Would you have been willing to discuss a menta...
# 189  Would you have been willing to discuss a menta...
# 190  Would you have been willing to discuss your me...
# 191  Would you have been willing to discuss your me...
# 192  Would you have felt more comfortable talking t...
#
#                                     col_list_2016_Cols  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# ...

# %%
def for_col_list_2016(row):
    if row["Total_List_Cols"]==row["col_list_2016_Cols"]:
        return 1
    else:
        return 0

def for_col_list_2017(row):
    if row["Total_List_Cols"]==row["col_list_2017_Cols"]:
        return 1
    else:
        return 0

def for_col_list_2018(row):
    if row["Total_List_Cols"]==row["col_list_2018_Cols"]:
        return 1
    else:
        return 0

def for_col_list_2019(row):
    if row["Total_List_Cols"]==row["col_list_2019_Cols"]:
        return 1
    else:
        return 0

def for_col_list_2020(row):
    if row["Total_List_Cols"]==row["col_list_2020_Cols"]:
        return 1
    else:
        return 0

def for_col_list_2021(row):
    if row["Total_List_Cols"]==row["col_list_2021_Cols"]:
        return 1
    else:
        return 0

def for_col_list_2022(row):
    if row["Total_List_Cols"]==row["col_list_2022_Cols"]:
        return 1
    else:
        return 0

def for_col_list_2023(row):
    if row["Total_List_Cols"]==row["col_list_2023_Cols"]:
        return 1
    else:
        return 0

comp_df["col_list_2016"]=comp_df.apply(for_col_list_2016, axis=1)
comp_df["col_list_2017"]=comp_df.apply(for_col_list_2017, axis=1)
comp_df["col_list_2018"]=comp_df.apply(for_col_list_2018, axis=1)
comp_df["col_list_2019"]=comp_df.apply(for_col_list_2019, axis=1)
comp_df["col_list_2020"]=comp_df.apply(for_col_list_2020, axis=1)
comp_df["col_list_2021"]=comp_df.apply(for_col_list_2021, axis=1)
comp_df["col_list_2022"]=comp_df.apply(for_col_list_2022, axis=1)
comp_df["col_list_2023"]=comp_df.apply(for_col_list_2023, axis=1)

# %%
comp_df.to_csv("resources/comp_df.csv", index=False)
